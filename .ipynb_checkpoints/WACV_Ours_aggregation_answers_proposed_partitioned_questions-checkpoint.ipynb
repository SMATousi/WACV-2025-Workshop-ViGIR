# %%
import ollama 
import os
from tqdm import tqdm
import json
import signal
import argparse
import wandb
import pandas as pd
import matplotlib.pyplot as plt
import copy
import numpy as np
import re

import sys
from collections import defaultdict

# %%
sys.argv = [
    'notebook',  
    '--modelname', 'llama3.2-vision:90b',
    '--data', 'gully',
    '--data_path','/mnt/jacket/WACV-2025-Workshop-ViGIR/results/proposed/test_19Q_llama3.2-vision:90b.json', #test_llama3_90b.json',
    '--subset', 'train',
    '--results_dir', '/mnt/jacket/WACV-2025-Workshop-ViGIR/results/proposed',
    '--timeout', '20',
    '--model_unloading'
]

# %%
parser = argparse.ArgumentParser(description="A script to evaluate V-LLMs on different image classification datasets")

parser.add_argument("--modelname", type=str, required=True, help="The name of the V-LLM model")
parser.add_argument("--data", type=str, required=True, help="Dataset name")
parser.add_argument("--data_path", type=str, required=True, help="Path to the image data dir")
parser.add_argument("--subset", type=str, required=True, help="train, test or validation set")
parser.add_argument("--results_dir", type=str, required=True, help="Folder name to save results")
parser.add_argument("--timeout", type=int, default=40, help="time out duration to skip one sample")
parser.add_argument("--model_unloading", action="store_true", help="Enables unloading mode. Every 100 samples it unloades the model from the GPU to avoid carshing.")

args = parser.parse_args()

# %%
# Load test set:
file_path = os.path.join(args.data_path)
with open(file_path, 'r') as file:
    data = json.load(file)

print('Number of Annotated GT Images: ', len(data.keys()))
data_keys_test = list(data.keys())
print('Number of Annotated GT Images (List): ', len(data_keys_test))
# Out:
# Number of Annotated GT Images:  311
# Number of Annotated GT Images (List):  311

# %%
data
# Out:
# {'415': [[{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Dr.Lory']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '1020': [[{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Krystal', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '105': [[{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'David']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '439': [[{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Parth', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '914': [[{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '1099': [[{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Pankaj', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '1065': [[{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Brian', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '373': [[{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Ali', 'Pankaj']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '166': [[{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '396': [[{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Brian', 'Yizheng']},
# ...
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['Dr.Lory', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '212': [[{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '4', 'labelers': ['David', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '131': [[{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['David', 'Parth']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '1133': [[{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   [{'label': '0', 'labelers': ['Ali', 'Yizheng']},
#    'Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']]}

# %%
data_reformated = {}

for key, item in data.items():
    q_and_a = []
    for i in range(len(item)):
        tmp = item[i][1:]   
        q_and_a.append(tmp)

    data_reformated[key] = q_and_a

# %%
data_reformated
# Out:
# {'415': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '1020': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '105': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '439': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '914': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '1099': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '1065': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '373': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '166': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '396': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '837': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '685': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '226': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
# ...
#    'No.']],
#  '973': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '212': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '131': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']],
#  '1133': [['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any indication of human activity such as tillage that is not naturally happening in the field? Answer with yes or no only!',
#    'No.']]}

# %%
num_questions = 18
#idx = [i for i in range(num_questions)]

if num_questions == 3:
    idx = [1,2,13]
elif  num_questions == 6:
    idx = [1,2,13,4,3,5]
elif  num_questions == 9:
    idx = [1,2,13,4,3,5,8,10,12]
elif  num_questions == 12:
    idx = [1,2,13,4,3,5,8,10,12,7,9,6]
elif  num_questions == 15:
    idx = [1,2,13,4,3,5,8,10,12,7,9,6,0,11,14]
elif  num_questions == 18:
    idx = [1,2,13,4,3,5,8,10,12,7,9,6,0,11,14,15,16,17]

data_reformated_final = copy.deepcopy(data_reformated)
for key, item in data_reformated_final.items():
    data_reformated_final[key] = [data_reformated_final[key][i] for i in idx]

# %%
data_reformated_final
# Out:
# {'415': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '1020': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '105': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '439': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '914': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '1099': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '1065': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '373': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '166': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '396': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '837': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '685': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '226': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
# ...
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '973': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'Yes.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '212': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '131': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']],
#  '1133': [['Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!',
#    'No.'],
#   ['Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!',
#    'No.']]}

# %%
data_prompt = {}
for key, item in data_reformated_final.items():
    prompt = "\n".join([f"Q: {qa[0]}\nA: {qa[1]}" for qa in item])
    data_prompt[key] = [prompt]

# %%
data_prompt
# Out:
# {'415': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '1020': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '105': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '439': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '914': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '1099': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '1065': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '373': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '166': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '396': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '837': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '685': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '226': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
# ...
#  '973': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: Yes.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '212': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '131': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.'],
#  '1133': ['Q: Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any sign of water flow patterns across the field in multiple images? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any edges in the images indicating removal of soil along the water pathway? Answer with yes or no only!\nA: No.\nQ: Given these six images of the exact same area and collected over a period of 10 years, do you see any cuts in the soil associated with water flow across the field? Answer with yes or no only!\nA: No.']}

# %%
model_name = args.modelname
ollama.pull(model_name)

timeout_duration = args.timeout

options= {  # new
            "seed": 123,
            "temperature": 0,
            "num_ctx": 2048, # must be set, otherwise slightly random output
        }

model_labels = {}
count = 0

# %%
count = 0
saving_response=copy.deepcopy(data_prompt)

for key, info in tqdm(data_prompt.items()):

    #print(key)
    #print(info[0])
    #sys.exit()
    question = "Based on the following questions and their answers, determine if there is evidence of an ephemeral gully in the observed area. Carefully analyze all the questions and the responses to assess.\n\n"
    question += info[0]
    question += "\n\nAfter considering these responses, provide a clear conclusion: Is there evidence of an ephemeral gully? Answer with yes or no only."
    
    #print(question)
    #sys.exit()
        
    count+=1
    #for question in questions:
    response = ollama.generate(model=model_name, 
                               prompt=question, 
                               #images=info, 
                               options=options)
    saving_response[key].append(response['response'])
    print(response['response'])

    #sys.exit()
# Out:
#   0%|▍                                                                                                                                       | 1/311 [04:50<24:59:23, 290.20s/it]
# No.
#   1%|▊                                                                                                                                       | 2/311 [04:51<10:17:56, 119.99s/it]
# No.
#   1%|█▎                                                                                                                                        | 3/311 [04:52<5:37:23, 65.72s/it]
# No.
#   1%|█▊                                                                                                                                        | 4/311 [04:53<3:25:50, 40.23s/it]
# No.
#   2%|██▏                                                                                                                                       | 5/311 [05:10<2:42:09, 31.80s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Channels**: The appearance of narrow and shallow channels that become intermittently deeper or more indented into the soil (Q4) is a strong indicator of ephemeral gullies, which are characterized by their temporary nature.
#
# 2. **Soil Disturbance and Vegetation Removal**: Areas where soil appears disturbed or vegetation is removed (Q6), especially in patterns suggesting an evolving channel (Q15), can indicate areas where water flow has been significant enough to alter the landscape temporarily.
#
# 3. **Varying Soil Exposure and Texture**: The varying exposure of lighter or darker colored soil (Q9) and varying types and levels of coarseness in the texture of the soil (Q11) could suggest erosion and deposition patterns typical of ephemeral gullies.
#
# 4. **Low Points in Terrain**: The presence of a low point in the terrain (Q16), which can act as a natural drainage line, supports the possibility of ephemeral gully formation.
#
# While not all questions provided affirmative answers indicative of an ephemeral gully, the cumulative evidence from several key indicators suggests that there is indeed evidence of an ephemeral gully in the observed area.
#   2%|██▋                                                                                                                                       | 6/311 [05:11<1:49:21, 21.51s/it]
# No.
#   2%|███                                                                                                                                       | 7/311 [05:13<1:15:36, 14.92s/it]
# No.
#   3%|███▌                                                                                                                                        | 8/311 [05:14<53:31, 10.60s/it]
# No.
#   3%|████                                                                                                                                        | 9/311 [05:15<38:19,  7.62s/it]
# No.
#   3%|████▍                                                                                                                                      | 10/311 [05:16<28:11,  5.62s/it]
# No.
#   4%|████▉                                                                                                                                      | 11/311 [05:17<21:06,  4.22s/it]
# No.
#   4%|█████▎                                                                                                                                     | 12/311 [05:26<28:10,  5.65s/it]
# Yes.
#
# Although not all questions provided definitive evidence, several answers collectively suggest characteristics typical of an ephemeral gully, such as intermittent recurrent winding paths (Q2), narrow and shallow channels that appear intermittently deeper or more indented into the soil (Q4), areas where soil appears disturbed or vegetation is removed (Q6), varying exposure of lighter or darker colored soil (Q8), varying types and levels of coarseness in the texture of the soil (Q10), a specific path lacking vegetation suggesting an evolving or emerging channel (Q12). These indicators, while not exhaustive, collectively point towards the presence of an ephemeral gully.
#   4%|█████▊                                                                                                                                     | 13/311 [05:32<28:23,  5.72s/it]
# Yes.
#
# Although most questions were answered "no", indicating that many typical signs of an ephemeral gully are not present, the presence of narrow and shallow channels which appear intermittently deeper or more indented into the soil (Q4) and a specific path lacking vegetation, suggesting an evolving or emerging channel (Q13), provide evidence for the existence of an ephemeral gully.
#   5%|██████▎                                                                                                                                    | 14/311 [05:34<22:04,  4.46s/it]
# No.
#   5%|██████▋                                                                                                                                    | 15/311 [05:34<16:35,  3.36s/it]
# No.
#   5%|███████▏                                                                                                                                   | 16/311 [05:36<13:34,  2.76s/it]
# No.
#   5%|███████▌                                                                                                                                   | 17/311 [05:37<11:27,  2.34s/it]
# No.
#   6%|████████                                                                                                                                   | 18/311 [05:38<09:57,  2.04s/it]
# No.
#   6%|████████▍                                                                                                                                  | 19/311 [05:39<08:08,  1.67s/it]
# No.
#   6%|████████▉                                                                                                                                  | 20/311 [05:40<06:47,  1.40s/it]
# No.
#   7%|█████████▍                                                                                                                                 | 21/311 [05:41<06:24,  1.32s/it]
# No.
#   7%|█████████▊                                                                                                                                 | 22/311 [05:43<06:57,  1.45s/it]
# Yes.
#   7%|██████████▎                                                                                                                                | 23/311 [05:45<07:21,  1.53s/it]
# No.
#   8%|███████████▏                                                                                                                               | 25/311 [05:46<04:54,  1.03s/it]
# No.
# No.
#   8%|███████████▌                                                                                                                               | 26/311 [05:47<05:03,  1.06s/it]
# No.
#   9%|████████████                                                                                                                               | 27/311 [05:48<05:26,  1.15s/it]
# No.
#   9%|████████████▌                                                                                                                              | 28/311 [05:49<05:15,  1.11s/it]
# No.
#  10%|█████████████▍                                                                                                                             | 30/311 [05:51<04:09,  1.13it/s]
# No.
# No.
#  10%|█████████████▊                                                                                                                             | 31/311 [06:09<28:14,  6.05s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key characteristics were identified across the images collected over 10 years:
#
# 1. **Intermittent Recurrent Winding Paths**: The presence of winding paths that become intermittent and recurrent suggests a pattern of water flow that is not constant but appears at certain times or conditions.
#
# 2. **Narrow and Shallow Channels**: The appearance of narrow and shallow channels which intermittently deepen or become more indented into the soil indicates areas where water may be flowing, creating these channels over time.
#
# 3. **Disturbed Soil/Vegetation Removal**: Areas with disturbed soil or removed vegetation could indicate where water flow has been significant enough to alter the surface.
#
# 4. **Lack of Vegetation Suggesting an Emerging Channel**: A specific path lacking vegetation suggests that it might be evolving into a channel, possibly due to repeated water flow.
#
# 5. **Low Point in Terrain**: The presence of a low point could act as a natural drainage line where ephemeral gullies often form.
#
# While not all questions provided positive indicators for an ephemeral gully (e.g., no clear starting and ending points of channels, no sediment accumulations), the combination of intermittent winding paths, narrow shallow channels, disturbed soil/vegetation removal, lack of vegetation suggesting a channel, and a low point in terrain collectively suggest that there is evidence of an ephemeral gully in the observed area.
#  10%|██████████████▎                                                                                                                            | 32/311 [06:11<22:06,  4.76s/it]
# No.
#  11%|██████████████▋                                                                                                                            | 33/311 [06:12<17:16,  3.73s/it]
# No.
#  11%|███████████████▋                                                                                                                           | 35/311 [06:14<09:57,  2.16s/it]
# No.
# No.
#  12%|████████████████                                                                                                                           | 36/311 [06:15<08:30,  1.86s/it]
# No.
#  12%|████████████████▌                                                                                                                          | 37/311 [06:30<27:18,  5.98s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Recurrent Winding Paths**: The appearance of winding paths that become intermittent recurrent over time is a strong indicator of water flow patterns typical of ephemeral gullies.
#
# 2. **Disturbed Soil and Removed Vegetation**: Areas where soil appears disturbed or vegetation is removed can indicate the path of an ephemeral gully, as these are common effects of water flow in such channels.
#
# 3. **Varying Exposure of Lighter or Darker Colored Soil**: This could suggest erosion and deposition patterns consistent with water activity, a hallmark of ephemeral gullies.
#
# 4. **Specific Path Lacking Vegetation**: A path lacking vegetation suggests an evolving or emerging channel, which is characteristic of how ephemeral gullies form and develop over time.
#
# 5. **Varying Types and Levels of Coarseness in Soil Texture**: This could indicate areas where water has altered the soil composition through erosion and deposition, a common feature around ephemeral gullies.
#
# While not all questions provided positive indicators, these key points collectively suggest that there is evidence of an ephemeral gully in the observed area.
#  12%|████████████████▉                                                                                                                          | 38/311 [06:32<21:24,  4.71s/it]
# No.
#  13%|█████████████████▍                                                                                                                         | 39/311 [06:33<16:45,  3.70s/it]
# No.
#  13%|█████████████████▉                                                                                                                         | 40/311 [06:46<28:56,  6.41s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Channels**: The appearance of narrow and shallow channels that become intermittently deeper or more indented into the soil (Q4) is a strong indicator of ephemeral gullies, which are characterized by their temporary nature.
#
# 2. **Soil Disturbance and Vegetation Removal**: Evidence of disturbed soil and removed vegetation in specific areas (Q6), along with paths lacking vegetation suggesting evolving channels (Q15), points towards the dynamic process associated with ephemeral gully formation.
#
# 3. **Varying Soil Exposure**: The varying exposure of lighter or darker colored soil (Q9) could indicate erosion patterns typical of ephemeral gullies, where water flow can expose underlying layers of soil.
#
# These indicators collectively suggest that despite not all questions yielding positive evidence for an ephemeral gully, there is sufficient information to conclude that such a feature exists in the observed area.
#  13%|██████████████████▎                                                                                                                        | 41/311 [06:48<22:15,  4.95s/it]
# No.
#  14%|██████████████████▊                                                                                                                        | 42/311 [06:49<17:19,  3.86s/it]
# No.
#  14%|███████████████████▋                                                                                                                       | 44/311 [06:50<09:44,  2.19s/it]
# No.
# No.
#  14%|████████████████████                                                                                                                       | 45/311 [06:52<08:33,  1.93s/it]
# No.
#  15%|████████████████████▌                                                                                                                      | 46/311 [06:53<07:44,  1.75s/it]
# No.
#  15%|█████████████████████                                                                                                                      | 47/311 [06:54<06:53,  1.57s/it]
# No.
#  15%|█████████████████████▍                                                                                                                     | 48/311 [06:55<06:18,  1.44s/it]
# No.
#  16%|█████████████████████▉                                                                                                                     | 49/311 [06:56<05:29,  1.26s/it]
# No.
#  16%|██████████████████████▎                                                                                                                    | 50/311 [06:57<05:34,  1.28s/it]
# No.
#  16%|██████████████████████▊                                                                                                                    | 51/311 [06:58<04:59,  1.15s/it]
# No.
#  17%|███████████████████████▏                                                                                                                   | 52/311 [06:59<04:57,  1.15s/it]
# No.
#  17%|███████████████████████▋                                                                                                                   | 53/311 [07:01<05:10,  1.20s/it]
# No.
#  17%|████████████████████████▏                                                                                                                  | 54/311 [07:03<05:54,  1.38s/it]
# Yes.
#  18%|████████████████████████▌                                                                                                                  | 55/311 [07:04<06:25,  1.51s/it]
# No.
#  18%|█████████████████████████                                                                                                                  | 56/311 [07:06<05:55,  1.40s/it]
# No.
#  18%|█████████████████████████▍                                                                                                                 | 57/311 [07:07<05:49,  1.38s/it]
# No.
#  19%|█████████████████████████▉                                                                                                                 | 58/311 [07:08<05:45,  1.37s/it]
# No.
#  19%|██████████████████████████▎                                                                                                                | 59/311 [07:24<24:28,  5.83s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Channels**: The appearance of narrow and shallow channels that become intermittently deeper or more indented into the soil (Q4) is a strong indicator of ephemeral gullies, which are characterized by their temporary nature.
#
# 2. **Soil Disturbance and Vegetation Removal**: Areas where soil appears disturbed or vegetation is removed (Q6), along with paths lacking vegetation suggesting an evolving channel (Q15), point towards the dynamic changes associated with water flow in ephemeral gullies.
#
# 3. **Sediment Accumulations**: The formation of sediment accumulations (Q18) can be a result of the deposition process that occurs as water flows through these temporary channels, further supporting the presence of an ephemeral gully.
#
# 4. **Varying Soil Exposure and Texture**: While not all questions related to soil texture changes were affirmative, the varying exposure of lighter or darker colored soil (Q9) could indicate areas where soil has been eroded or deposited, consistent with the activity in ephemeral gullies.
#
# Given these observations, despite some negative responses that might suggest otherwise, there is sufficient evidence from multiple indicators to conclude that an ephemeral gully is present.
#  20%|███████████████████████████▎                                                                                                               | 61/311 [07:26<13:29,  3.24s/it]
# No.
# No.
#  20%|████████████████████████████▏                                                                                                              | 63/311 [07:27<06:57,  1.68s/it]
# No.
# No.
#  21%|████████████████████████████▌                                                                                                              | 64/311 [07:33<12:17,  2.99s/it]
# Yes.
#
# Although most questions were answered "no", indicating that many typical characteristics of ephemeral gullies were not observed, two key indicators were present: narrow and shallow channels which appear intermittently deeper or more indented into the soil (Q4), and a specific path lacking vegetation, suggesting an evolving or emerging channel (Q13). These signs are consistent with the formation of an ephemeral gully.
#  21%|█████████████████████████████                                                                                                              | 65/311 [07:34<10:28,  2.56s/it]
# No.
#  21%|█████████████████████████████▍                                                                                                             | 66/311 [07:35<08:18,  2.04s/it]
# No.
#  22%|█████████████████████████████▉                                                                                                             | 67/311 [07:36<07:26,  1.83s/it]
# No.
#  22%|██████████████████████████████▍                                                                                                            | 68/311 [07:50<21:22,  5.28s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key characteristics were identified across the images collected over 10 years:
#
# 1. **Intermittent Recurrent Winding Paths**: The presence of winding paths that become intermittent and recurrent suggests a pattern of water flow that is not constant but appears at certain times or conditions.
#
# 2. **Narrow and Shallow Channels**: The appearance of narrow and shallow channels which intermittently deepen or become more indented into the soil indicates areas where water may be flowing, creating these channels over time.
#
# 3. **Disturbed Soil/Vegetation Removal**: Areas with disturbed soil or removed vegetation could indicate where water flow has been significant enough to alter the surface conditions.
#
# 4. **Lack of Vegetation Suggesting an Emerging Channel**: A specific path lacking vegetation suggests that this area might be evolving into a channel, possibly due to repeated water flow.
#
# These indicators collectively suggest the presence of ephemeral gully characteristics in the observed area, despite not all questions yielding positive evidence.
#  22%|██████████████████████████████▊                                                                                                            | 69/311 [07:51<16:59,  4.21s/it]
# No.
#  23%|███████████████████████████████▋                                                                                                           | 71/311 [07:53<09:27,  2.36s/it]
# No.
# No.
#  23%|████████████████████████████████▏                                                                                                          | 72/311 [07:54<07:57,  2.00s/it]
# No.
#  23%|████████████████████████████████▋                                                                                                          | 73/311 [08:02<15:28,  3.90s/it]
# Yes.
#
# Although many questions received negative answers, some key indicators suggest the presence of an ephemeral gully. Specifically:
#
# - The appearance of intermittent recurrent winding paths (Q2) and a specific path lacking vegetation (Q16) are indicative of water flow patterns that could be associated with an ephemeral gully.
# - The varying exposure of lighter or darker colored soil (Q8) might suggest changes in the soil due to water activity, which is consistent with the formation of an ephemeral gully.
#
# These positive indicators outweigh the negative responses and provide evidence for the presence of an ephemeral gully.
#  24%|█████████████████████████████████                                                                                                          | 74/311 [08:04<12:50,  3.25s/it]
# No.
#  24%|█████████████████████████████████▌                                                                                                         | 75/311 [08:21<29:08,  7.41s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key characteristics were identified across the images collected over 10 years:
#
# 1. **Intermittent Recurrent Winding Paths**: The presence of winding paths that become intermittent and recurrent suggests a pattern of water flow that is not constant but appears at certain times or conditions.
#
# 2. **Narrow and Shallow Channels**: The appearance of narrow and shallow channels which intermittently deepen or become more indented into the soil indicates areas where water may be flowing, creating these channels over time.
#
# 3. **Soil Disturbance/Vegetation Removal**: Areas with disturbed soil or removed vegetation could indicate where water flow has been significant enough to alter the surface.
#
# 4. **Lack of Vegetation Suggesting an Emerging Channel**: A specific path lacking vegetation suggests that it might be evolving into a channel, possibly due to repeated water flow.
#
# 5. **Sediment Accumulations Forming**: The formation of sediment accumulations could indicate areas where water has deposited material carried from other parts of the field or surrounding landscape.
#
# While not all questions provided positive indicators for an ephemeral gully (e.g., no clear starting and ending points, no branching patterns resembling temporary streams), the cumulative evidence from several key characteristics supports the conclusion that there is indeed evidence of an ephemeral gully in the observed area.
#  24%|█████████████████████████████████▉                                                                                                         | 76/311 [08:23<22:20,  5.71s/it]
# No.
#  25%|██████████████████████████████████▍                                                                                                        | 77/311 [08:24<17:08,  4.40s/it]
# No.
#  25%|██████████████████████████████████▊                                                                                                        | 78/311 [08:25<13:16,  3.42s/it]
# No.
#  25%|███████████████████████████████████▎                                                                                                       | 79/311 [08:27<10:48,  2.79s/it]
# No.
#  26%|███████████████████████████████████▊                                                                                                       | 80/311 [08:27<08:28,  2.20s/it]
# No.
#  26%|████████████████████████████████████▏                                                                                                      | 81/311 [08:36<15:59,  4.17s/it]
# Yes.
#
# Although most questions were answered "no", indicating a lack of typical signs associated with ephemeral gullies such as winding paths, branching patterns, shallow channels, linear depressions, and sediment accumulations, one key question (Q2) was answered "yes". This indicates that there are intermittent recurrent winding paths in the observed area over time. Additionally, another question (Q16) also received a positive response, suggesting an evolving or emerging channel due to a lack of vegetation along a specific path.
#
# These two affirmative responses provide sufficient evidence to conclude that there is indeed an ephemeral gully present in the observed area.
#  26%|████████████████████████████████████▋                                                                                                      | 82/311 [08:38<13:07,  3.44s/it]
# No.
#  27%|█████████████████████████████████████                                                                                                      | 83/311 [08:39<10:40,  2.81s/it]
# No.
#  27%|█████████████████████████████████████▌                                                                                                     | 84/311 [08:41<08:57,  2.37s/it]
# No.
#  27%|█████████████████████████████████████▉                                                                                                     | 85/311 [08:42<07:45,  2.06s/it]
# No.
#  28%|██████████████████████████████████████▍                                                                                                    | 86/311 [08:43<06:54,  1.84s/it]
# No.
#  28%|██████████████████████████████████████▉                                                                                                    | 87/311 [08:44<05:58,  1.60s/it]
# No.
#  29%|███████████████████████████████████████▊                                                                                                   | 89/311 [08:46<04:09,  1.12s/it]
# No.
# No.
#  29%|████████████████████████████████████████▏                                                                                                  | 90/311 [08:47<03:48,  1.03s/it]
# No.
#  29%|████████████████████████████████████████▋                                                                                                  | 91/311 [08:48<04:07,  1.12s/it]
# No.
#  30%|█████████████████████████████████████████                                                                                                  | 92/311 [08:49<04:20,  1.19s/it]
# No.
#  30%|█████████████████████████████████████████▌                                                                                                 | 93/311 [08:50<03:55,  1.08s/it]
# No.
#  30%|██████████████████████████████████████████                                                                                                 | 94/311 [09:06<19:42,  5.45s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Recurrent Winding Paths**: The appearance of winding paths that become intermittent recurrent over time is a strong indicator of water flow patterns typical of ephemeral gullies.
#
# 2. **Disturbed Soil and Removed Vegetation**: Areas where soil appears disturbed or vegetation is removed can indicate the path of an ephemeral gully, as these are common effects of water flow in such channels.
#
# 3. **Varying Exposure of Lighter or Darker Colored Soil**: This could suggest erosion and deposition patterns consistent with water activity, a hallmark of ephemeral gullies.
#
# 4. **Specific Path Lacking Vegetation**: A path lacking vegetation suggests an evolving or emerging channel, which is characteristic of how ephemeral gullies form and develop over time.
#
# 5. **Varying Types and Levels of Coarseness in Soil Texture**: This could indicate areas where water has altered the soil composition through erosion and deposition, a common feature around ephemeral gullies.
#
# While not all questions provided positive indicators, these key points collectively suggest that there is evidence of an ephemeral gully in the observed area.
#  31%|██████████████████████████████████████████▍                                                                                                | 95/311 [09:08<15:36,  4.34s/it]
# No.
#  31%|██████████████████████████████████████████▉                                                                                                | 96/311 [09:09<12:06,  3.38s/it]
# No.
#  32%|███████████████████████████████████████████▊                                                                                               | 98/311 [09:10<06:55,  1.95s/it]
# No.
# No.
#  32%|████████████████████████████████████████████▏                                                                                              | 99/311 [09:11<06:14,  1.77s/it]
# No.
#  32%|████████████████████████████████████████████▎                                                                                             | 100/311 [09:13<05:46,  1.64s/it]
# No.
#  32%|████████████████████████████████████████████▊                                                                                             | 101/311 [09:14<04:53,  1.40s/it]
# No.
#  33%|█████████████████████████████████████████████▎                                                                                            | 102/311 [09:15<04:47,  1.38s/it]
# No.
#  33%|█████████████████████████████████████████████▋                                                                                            | 103/311 [09:16<04:44,  1.37s/it]
# No.
#  33%|██████████████████████████████████████████████▏                                                                                           | 104/311 [09:17<04:29,  1.30s/it]
# No.
#  34%|██████████████████████████████████████████████▌                                                                                           | 105/311 [09:18<04:18,  1.25s/it]
# No.
#  34%|███████████████████████████████████████████████                                                                                           | 106/311 [09:20<04:45,  1.39s/it]
# Yes.
#  34%|███████████████████████████████████████████████▍                                                                                          | 107/311 [09:22<05:05,  1.50s/it]
# No.
#  35%|███████████████████████████████████████████████▉                                                                                          | 108/311 [09:23<04:54,  1.45s/it]
# No.
#  35%|████████████████████████████████████████████████▎                                                                                         | 109/311 [09:25<04:45,  1.41s/it]
# No.
#  35%|████████████████████████████████████████████████▊                                                                                         | 110/311 [09:25<04:09,  1.24s/it]
# No.
#  36%|█████████████████████████████████████████████████▎                                                                                        | 111/311 [09:26<03:42,  1.11s/it]
# No.
#  36%|█████████████████████████████████████████████████▋                                                                                        | 112/311 [09:28<04:18,  1.30s/it]
# No.
#  37%|██████████████████████████████████████████████████▌                                                                                       | 114/311 [09:30<03:28,  1.06s/it]
# No.
# No.
#  37%|███████████████████████████████████████████████████                                                                                       | 115/311 [09:31<03:43,  1.14s/it]
# No.
#  37%|███████████████████████████████████████████████████▍                                                                                      | 116/311 [09:33<03:54,  1.20s/it]
# No.
#  38%|███████████████████████████████████████████████████▉                                                                                      | 117/311 [09:34<03:49,  1.18s/it]
# No.
#  38%|████████████████████████████████████████████████████▎                                                                                     | 118/311 [09:35<03:27,  1.07s/it]
# No.
#  38%|████████████████████████████████████████████████████▊                                                                                     | 119/311 [09:35<03:12,  1.00s/it]
# No.
#  39%|█████████████████████████████████████████████████████▏                                                                                    | 120/311 [09:37<03:30,  1.10s/it]
# No.
#  39%|█████████████████████████████████████████████████████▋                                                                                    | 121/311 [09:38<03:13,  1.02s/it]
# No.
#  39%|██████████████████████████████████████████████████████▏                                                                                   | 122/311 [09:39<03:30,  1.11s/it]
# No.
#  40%|██████████████████████████████████████████████████████▌                                                                                   | 123/311 [09:41<04:03,  1.30s/it]
# Yes.
#  40%|███████████████████████████████████████████████████████                                                                                   | 124/311 [09:42<04:26,  1.43s/it]
# No.
#  40%|███████████████████████████████████████████████████████▍                                                                                  | 125/311 [09:43<04:03,  1.31s/it]
# No.
#  41%|███████████████████████████████████████████████████████▉                                                                                  | 126/311 [09:44<03:52,  1.26s/it]
# No.
#  41%|████████████████████████████████████████████████████████▎                                                                                 | 127/311 [09:46<03:39,  1.19s/it]
# No.
#  41%|████████████████████████████████████████████████████████▊                                                                                 | 128/311 [09:47<03:35,  1.18s/it]
# No.
#  41%|█████████████████████████████████████████████████████████▏                                                                                | 129/311 [09:48<03:43,  1.23s/it]
# No.
#  42%|█████████████████████████████████████████████████████████▋                                                                                | 130/311 [09:49<03:37,  1.20s/it]
# No.
#  42%|██████████████████████████████████████████████████████████▏                                                                               | 131/311 [09:50<03:43,  1.24s/it]
# No.
#  42%|██████████████████████████████████████████████████████████▌                                                                               | 132/311 [09:51<03:19,  1.12s/it]
# No.
#  43%|███████████████████████████████████████████████████████████                                                                               | 133/311 [09:52<03:19,  1.12s/it]
# No.
#  43%|███████████████████████████████████████████████████████████▍                                                                              | 134/311 [09:54<03:30,  1.19s/it]
# No.
#  43%|███████████████████████████████████████████████████████████▉                                                                              | 135/311 [09:55<03:37,  1.23s/it]
# No.
#  44%|████████████████████████████████████████████████████████████▎                                                                             | 136/311 [10:01<07:47,  2.67s/it]
# Yes.
#
# Although most questions were answered "no", indicating that many typical characteristics of ephemeral gullies were not observed, two key indicators were present: narrow and shallow channels which appear intermittently deeper or more indented into the soil (Q4), and a specific path lacking vegetation, suggesting an evolving or emerging channel (Q13). These signs are consistent with the formation of an ephemeral gully.
#  44%|████████████████████████████████████████████████████████████▊                                                                             | 137/311 [10:03<06:45,  2.33s/it]
# No.
#  45%|█████████████████████████████████████████████████████████████▋                                                                            | 139/311 [10:04<04:07,  1.44s/it]
# No.
# No.
#  45%|██████████████████████████████████████████████████████████████                                                                            | 140/311 [10:05<04:00,  1.41s/it]
# No.
#  45%|██████████████████████████████████████████████████████████████▌                                                                           | 141/311 [10:12<08:32,  3.02s/it]
# Yes.
#
# Although most questions were answered "no", indicating that typical characteristics of ephemeral gullies such as winding paths, branching patterns, and linear depressions are not present, some responses suggest the presence of features associated with ephemeral gullies. For example, areas where soil appears disturbed or vegetation is removed (Q6), a specific path lacking vegetation suggesting an evolving channel (Q15), and sediment accumulations forming (Q18) could be indicative of water flow and erosion patterns typical of ephemeral gullies.
#  46%|███████████████████████████████████████████████████████████████                                                                           | 142/311 [10:13<06:49,  2.42s/it]
# No.
#  46%|███████████████████████████████████████████████████████████████▍                                                                          | 143/311 [10:27<16:03,  5.74s/it]
# Yes.
#
# Although many questions were answered "no", indicating that some typical characteristics of ephemeral gullies (such as winding paths, branching patterns, and sediment accumulations) are not present in the images, a few key indicators suggest the presence of an ephemeral gully:
#
# 1. The answer to Q2 ("Given these six images...are there winding paths that become intermittent recurrent?") is "yes", which suggests that there may be temporary or seasonal water flow patterns.
# 2. The answer to Q6 ("Given these six images...are there areas where soil appears disturbed or vegetation is removed?") is "yes", indicating possible erosion or disturbance of the soil and vegetation, consistent with ephemeral gully formation.
# 3. The answer to Q20 ("Given these six images...does a specific path lack vegetation, suggesting an evolving or emerging channel?") is also "yes", which further supports the presence of an ephemeral gully.
#
# Considering these positive indicators, it appears that there is evidence of an ephemeral gully in the observed area.
#  46%|███████████████████████████████████████████████████████████████▉                                                                          | 144/311 [10:28<12:37,  4.54s/it]
# No.
#  47%|████████████████████████████████████████████████████████████████▎                                                                         | 145/311 [10:30<09:53,  3.58s/it]
# No.
#  47%|████████████████████████████████████████████████████████████████▊                                                                         | 146/311 [10:31<07:59,  2.90s/it]
# No.
#  47%|█████████████████████████████████████████████████████████████████▏                                                                        | 147/311 [10:32<06:29,  2.37s/it]
# No.
#  48%|█████████████████████████████████████████████████████████████████▋                                                                        | 148/311 [10:38<09:02,  3.33s/it]
# Yes.
#
# Although most questions were answered "no", one question (Q4) was answered "yes" indicating the presence of narrow and shallow channels which appear intermittently deeper or more indented into the soil, a characteristic often associated with ephemeral gullies. This single affirmative response provides evidence for the existence of an ephemeral gully in the observed area.
#  48%|██████████████████████████████████████████████████████████████████                                                                        | 149/311 [10:39<07:31,  2.79s/it]
# No.
#  48%|██████████████████████████████████████████████████████████████████▌                                                                       | 150/311 [10:55<17:40,  6.58s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Recurrent Winding Paths**: The appearance of winding paths that become intermittent recurrent over time is a strong indicator of water flow patterns typical of ephemeral gullies.
#
# 2. **Disturbed Soil and Removed Vegetation**: Areas where soil appears disturbed or vegetation is removed can indicate the path of an ephemeral gully, as these are common effects of water flow in such channels.
#
# 3. **Varying Exposure of Lighter or Darker Colored Soil**: This could suggest erosion and deposition patterns consistent with water activity, a hallmark of ephemeral gullies.
#
# 4. **Specific Path Lacking Vegetation**: A path lacking vegetation suggests an evolving or emerging channel, which is characteristic of how ephemeral gullies form and develop over time.
#
# 5. **Varying Types and Levels of Coarseness in Soil Texture**: This could indicate areas where water has altered the soil composition through erosion and deposition, a common feature around ephemeral gullies.
#
# While not all questions provided positive indicators, these key points collectively suggest that there is evidence of an ephemeral gully in the observed area.
#  49%|███████████████████████████████████████████████████████████████████                                                                       | 151/311 [10:56<13:40,  5.13s/it]
# No.
#  49%|███████████████████████████████████████████████████████████████████▍                                                                      | 152/311 [10:58<10:53,  4.11s/it]
# Yes.
#  49%|███████████████████████████████████████████████████████████████████▉                                                                      | 153/311 [11:00<08:56,  3.39s/it]
# No.
#  50%|████████████████████████████████████████████████████████████████████▎                                                                     | 154/311 [11:16<18:50,  7.20s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Channels**: The appearance of narrow and shallow channels that become intermittently deeper or more indented into the soil (Q4) is a strong indicator of ephemeral gullies, which are characterized by their temporary nature.
#
# 2. **Soil Disturbance and Vegetation Removal**: Areas where soil appears disturbed or vegetation is removed (Q6), along with paths lacking vegetation suggesting an evolving channel (Q15), point towards the dynamic changes associated with water flow in ephemeral gullies.
#
# 3. **Sediment Accumulations**: The formation of sediment accumulations (Q18) can be a result of the deposition process that occurs as water flows through these temporary channels, further supporting the presence of an ephemeral gully.
#
# 4. **Varying Soil Exposure and Texture**: While not all questions related to soil texture changes were affirmative, the varying exposure of lighter or darker colored soil (Q9) could indicate areas where soil has been eroded or deposited, consistent with the activity in ephemeral gullies.
#
# Given these observations, despite some negative responses that might suggest otherwise, there is sufficient evidence from multiple indicators to conclude that an ephemeral gully is present.
#  50%|████████████████████████████████████████████████████████████████████▊                                                                     | 155/311 [11:18<14:18,  5.50s/it]
# No.
#  50%|█████████████████████████████████████████████████████████████████████▏                                                                    | 156/311 [11:33<21:53,  8.48s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Recurrent Winding Paths**: The appearance of winding paths that become intermittent recurrent over time is a strong indicator of water flow patterns typical of ephemeral gullies.
#
# 2. **Disturbed Soil and Removed Vegetation**: Areas where soil appears disturbed or vegetation is removed can indicate the path of an ephemeral gully, as these are common effects of water flow in such channels.
#
# 3. **Varying Exposure of Lighter or Darker Colored Soil**: This could suggest erosion and deposition patterns consistent with water activity, a hallmark of ephemeral gullies.
#
# 4. **Specific Path Lacking Vegetation**: A path lacking vegetation suggests an evolving or emerging channel, which is characteristic of how ephemeral gullies form and develop over time.
#
# 5. **Varying Types and Levels of Coarseness in Soil Texture**: This could indicate areas where water has altered the soil composition through erosion and deposition, a common feature around ephemeral gullies.
#
# While not all questions provided positive indicators, these key points collectively suggest that there is evidence of an ephemeral gully in the observed area.
#  51%|██████████████████████████████████████████████████████████████████████                                                                    | 158/311 [11:35<11:40,  4.58s/it]
# No.
# No.
#  51%|██████████████████████████████████████████████████████████████████████▌                                                                   | 159/311 [11:36<09:07,  3.60s/it]
# No.
#  51%|██████████████████████████████████████████████████████████████████████▉                                                                   | 160/311 [11:55<20:26,  8.12s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Channels**: The appearance of narrow and shallow channels that become intermittently deeper or more indented into the soil (Q4) is a strong indicator of ephemeral gullies, which are characterized by their temporary nature.
#
# 2. **Soil Disturbance and Vegetation Removal**: Evidence of disturbed soil and removed vegetation in specific areas (Q6) can be indicative of water flow that might not always be visible but has enough impact to alter the surface.
#
# 3. **Varying Soil Exposure and Texture**: The varying exposure of lighter or darker colored soil (Q8) and changes in soil texture coarseness (Q10) could suggest erosion patterns typical of ephemeral gullies, where water flow can expose underlying layers or deposit material.
#
# 4. **Path Lacking Vegetation**: A specific path lacking vegetation (Q13), suggesting an evolving or emerging channel, is a direct indicator of the formation process of an ephemeral gully.
#
# 5. **Absence of Human Activity and Other Features**: The lack of evidence pointing to human activity (Q16) or other features that could explain these observations (like sediment accumulations, machinery tracks, etc.) supports the interpretation that natural processes, such as those leading to ephemeral gullies, are at play.
#
# ...
# No.
#  81%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                          | 251/311 [15:27<01:14,  1.24s/it]
# No.
#  81%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                          | 252/311 [15:28<01:11,  1.21s/it]
# No.
#  81%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                         | 253/311 [15:30<01:12,  1.25s/it]
# No.
#  82%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                         | 254/311 [15:31<01:09,  1.21s/it]
# No.
#  82%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                        | 255/311 [15:32<01:09,  1.25s/it]
# No.
#  83%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████                        | 257/311 [15:34<00:51,  1.05it/s]
# No.
# No.
#  83%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                       | 258/311 [15:34<00:38,  1.39it/s]
# No.
#  83%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                       | 259/311 [15:35<00:47,  1.10it/s]
# No.
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                      | 260/311 [15:37<00:58,  1.15s/it]
# No.
#  84%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                      | 261/311 [15:39<01:06,  1.33s/it]
# No.
#  85%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                     | 263/311 [15:40<00:47,  1.01it/s]
# No.
# No.
#  85%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌                    | 265/311 [15:42<00:37,  1.21it/s]
# No.
# No.
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                    | 266/311 [15:42<00:28,  1.57it/s]
# No.
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍                   | 267/311 [15:43<00:34,  1.27it/s]
# No.
#  86%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉                   | 268/311 [15:50<01:54,  2.67s/it]
# Yes.
#
# Although most questions were answered "no", indicating that typical characteristics of ephemeral gullies such as winding paths, branching patterns, and linear depressions are not present, some responses suggest signs of water activity and soil disturbance. The presence of disturbed soil (Q7), varying exposure of lighter or darker colored soil (Q9), sediment accumulations forming (Q19), and a specific path lacking vegetation (Q15) collectively point towards the possibility of an ephemeral gully in the observed area.
#  86%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                  | 269/311 [15:51<01:35,  2.27s/it]
# No.
#  87%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊                  | 270/311 [15:59<02:37,  3.83s/it]
# Yes.
#
# Although most questions were answered "no", indicating that many typical characteristics of ephemeral gullies are not present in the images, two key indicators suggest otherwise:
#
# 1. The presence of narrow and shallow channels which appear intermittently deeper or more indented into the soil (Q4).
# 2. Areas where soil appears disturbed or vegetation is removed (Q6), combined with varying exposure of lighter or darker colored soil (Q8).
#
# These signs collectively point towards potential ephemeral gully formation, despite the absence of other typical features.
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎                 | 271/311 [16:00<02:05,  3.15s/it]
# No.
#  87%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋                 | 272/311 [16:02<01:41,  2.60s/it]
# No.
#  88%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏                | 273/311 [16:03<01:24,  2.22s/it]
# No.
#  88%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                | 275/311 [16:04<00:49,  1.39s/it]
# No.
# No.
#  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍               | 276/311 [16:06<00:48,  1.37s/it]
# No.
#  89%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉               | 277/311 [16:07<00:44,  1.30s/it]
# No.
#  89%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎              | 278/311 [16:08<00:43,  1.31s/it]
# No.
#  90%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊              | 279/311 [16:09<00:40,  1.26s/it]
# No.
#  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏             | 280/311 [16:18<01:48,  3.50s/it]
# Yes.
#
# Although most questions were answered "no", indicating a lack of typical signs associated with ephemeral gullies such as winding paths, branching patterns, shallow channels, linear depressions, and sediment accumulations, one key question (Q2) was answered "yes". This indicates that there are intermittent recurrent winding paths in the observed area over time. Additionally, another question (Q16) also received a positive response, suggesting an evolving or emerging channel due to a lack of vegetation along a specific path.
#
# These two affirmative responses provide sufficient evidence to conclude that there is indeed an ephemeral gully present in the observed area.
#  90%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋             | 281/311 [16:31<03:07,  6.25s/it]
# Yes.
#
# Although not all questions provided definitive evidence, several answers collectively suggest the presence of an ephemeral gully:
#
# - The appearance of intermittent recurrent winding paths (Q2) and areas where soil appears disturbed or vegetation is removed (Q6) indicate potential water flow activity.
# - Varying exposure of lighter or darker colored soil (Q8), varying types and levels of coarseness in the texture of the soil (Q10), sediment accumulations forming (Q18), and a specific path lacking vegetation, suggesting an evolving or emerging channel (Q15), all point to changes that could be associated with water flow.
# - The lack of clear starting and ending points of potential channels (Q7) and no signs of water activity like soil clumps or crusting (Q11) do not necessarily rule out the presence of an ephemeral gully, as these features can vary over time.
#
# Considering all responses together, there is enough evidence to suggest that an ephemeral gully might be present in the observed area.
#  91%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌            | 283/311 [16:33<01:37,  3.48s/it]
# No.
# No.
#  91%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████            | 284/311 [16:33<01:07,  2.50s/it]
# No.
#  92%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍           | 285/311 [16:34<00:51,  2.00s/it]
# No.
#  92%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉           | 286/311 [16:35<00:43,  1.74s/it]
# No.
#  92%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎          | 287/311 [16:37<00:41,  1.74s/it]
# Yes.
#  93%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊          | 288/311 [16:38<00:39,  1.74s/it]
# No.
#  93%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏         | 289/311 [16:40<00:35,  1.62s/it]
# No.
#  93%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋         | 290/311 [16:41<00:32,  1.53s/it]
# No.
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏        | 291/311 [16:42<00:28,  1.41s/it]
# No.
#  94%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌        | 292/311 [16:44<00:26,  1.39s/it]
# No.
#  94%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████        | 293/311 [16:45<00:24,  1.37s/it]
# No.
#  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▍       | 294/311 [16:46<00:20,  1.21s/it]
# No.
#  95%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉       | 295/311 [16:46<00:17,  1.09s/it]
# No.
#  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎      | 296/311 [16:48<00:17,  1.16s/it]
# No.
#  95%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊      | 297/311 [16:56<00:45,  3.28s/it]
# Yes.
#
# (Note: The presence of narrow and shallow channels that appear intermittently deeper or more indented into the soil (Q4), areas where soil appears disturbed or vegetation is removed (Q6), varying exposure of lighter or darker colored soil (Q8), varying types and levels of coarseness in the texture of the soil (Q10), a specific path lacking vegetation suggesting an evolving or emerging channel (Q12), low points in the terrain (Q14), sediment accumulations forming (Q16), and lack of human activity indications, collectively suggest evidence of an ephemeral gully.)
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏     | 298/311 [17:12<01:31,  7.03s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Channels**: The appearance of narrow and shallow channels that become intermittently deeper or more indented into the soil (Q4) is a strong indicator of ephemeral gullies, which are characterized by their temporary nature.
#
# 2. **Soil Disturbance and Vegetation Removal**: Evidence of disturbed soil and removed vegetation in specific areas (Q6) can be indicative of water flow that might not always be visible but has enough impact to alter the surface.
#
# 3. **Varying Soil Exposure and Texture**: The varying exposure of lighter or darker colored soil (Q8) and changes in soil texture coarseness (Q10) could suggest erosion patterns typical of ephemeral gullies, where water flow can expose different layers of soil or deposit materials that alter the surface texture.
#
# 4. **Path Lacking Vegetation**: A specific path lacking vegetation (Q13), suggesting an evolving or emerging channel, is a direct indicator of potential ephemeral gully formation. This lack of vegetation could be due to repeated water flow that prevents plant growth in those areas.
#
# While not all questions provided positive indicators for an ephemeral gully, the combination of these key points strongly suggests its presence in the observed area.
#  96%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋     | 299/311 [17:13<01:04,  5.39s/it]
# No.
#  96%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████     | 300/311 [17:29<01:34,  8.60s/it]
# Yes.
#
# Although not all questions provided definitive indicators of an ephemeral gully, several key points suggest its presence:
#
# 1. **Intermittent Channels**: The appearance of narrow and shallow channels that become intermittently deeper or more indented into the soil (Q4) is a strong indicator of ephemeral gullies, which are characterized by their temporary nature.
#
# 2. **Soil Disturbance and Vegetation Removal**: Evidence of disturbed soil and removed vegetation in specific areas (Q6) can be indicative of water flow that might not always be visible but has enough impact to alter the surface.
#
# 3. **Varying Soil Texture**: The presence of varying types and levels of coarseness in the texture of the soil (Q10) could suggest erosion patterns typical of ephemeral gullies, where different materials are deposited or eroded at various times.
#
# 4. **Path Lacking Vegetation**: A specific path lacking vegetation (Q13), suggesting an evolving or emerging channel, is a direct indicator of potential water flow paths that might not be permanent but recur under certain conditions.
#
# While other questions did not yield positive indicators for ephemeral gullies, the combination of these affirmative responses provides sufficient evidence to conclude that there is indeed evidence of an ephemeral gully in the observed area.
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌    | 301/311 [17:31<01:04,  6.48s/it]
# No.
#  97%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████    | 302/311 [17:33<00:45,  5.05s/it]
# Yes.
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▉   | 304/311 [17:35<00:20,  2.90s/it]
# No.
# No.
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▎  | 305/311 [17:36<00:14,  2.37s/it]
# No.
#  98%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▊  | 306/311 [17:38<00:10,  2.18s/it]
# No.
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▏ | 307/311 [17:39<00:08,  2.04s/it]
# No.
#  99%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▋ | 308/311 [17:41<00:05,  1.83s/it]
# No.
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████▌| 310/311 [17:42<00:01,  1.24s/it]
# No.
# No.
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 311/311 [17:42<00:00,  3.42s/it]
# No.

# %%
# Save the dictionary as a JSON file
filename =  'results_'+str(num_questions)+'Q_'+args.modelname+'_raw.json'
with open(os.path.join(args.results_dir, filename), 'w') as json_file:
    json.dump(saving_response, json_file, indent=4)

print(f"JSON file {filename} has been created.")
# Out:
# JSON file results_18Q_llama3.2-vision:90b_raw.json has been created.

# %%
def extract_first_yes_no(text):
    # Use regular expressions to find "Yes" or "No" (case-insensitive)
    match = re.search(r'\b(Yes|No)\b', text, re.IGNORECASE)
    if match:
        # Return the first match in its original case
        return match.group(0)
    return None

# %%
saving_response_reformat = {}

for key, item in saving_response.items():
    #print(key)
    #print(item[-1])
    text = extract_first_yes_no(item[-1])

    print(f"Image: {key} - Answer: {text}")
    
    if text == 'Yes':
        saving_response_reformat[key] = ["4"]

    if text == 'No':
        saving_response_reformat[key] = ["0"]

# %%
saving_response_reformat

# %%
# Save the dictionary as a JSON file
filename =  'results_'+str(num_questions)+'Q_'+args.modelname+'.json'
with open(os.path.join(args.results_dir, filename), 'w') as json_file:
    json.dump(saving_response_reformat, json_file, indent=4)

print(f"JSON file {filename} has been created.")
