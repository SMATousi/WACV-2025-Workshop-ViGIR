# %%
import ollama 
import os
from tqdm import tqdm
import json
import signal
import argparse
import wandb
import pandas as pd
import matplotlib.pyplot as plt
import copy

import sys
from collections import defaultdict

#from  utilities import *

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
list_of_models = ['llava:7b', 'llava:13b', 'llava:34b', 'llama3.2-vision:90b', 'llava-llama3:8b']

# %%
sys.argv = [
    'notebook',  
    '--modelname', 'minicpm-v:8b',
    '--data', 'gully',
    '--data_path','/home/data/',
    "--data_samples", 'train.jsonl',
    "--subset", 'train',
    '--results_dir', '/mnt/jacket/WACV-2025-Workshop-ViGIR/results/proposed',
    '--timeout', '20',
    '--model_unloading'
]

# %%
parser = argparse.ArgumentParser(description="A script to run V-LLMs on different image classification datasets")

# %%
# set up the argument parser
parser.add_argument("--modelname", type=str, required=True, help="The name of the V-LLM model")
parser.add_argument("--data", type=str, required=True, help="Dataset name")
parser.add_argument("--data_path", type=str, required=True, help="Path to the image data dir")
parser.add_argument("--data_samples", type=str, required=True, help="Name of the samples to run on")
parser.add_argument("--subset", type=str, required=True, help="train, test or validation set")
parser.add_argument("--results_dir", type=str, required=True, help="Folder name to save results")
parser.add_argument("--timeout", type=int, default=40, help="time out duration to skip one sample")
parser.add_argument("--model_unloading", action="store_true", help="Enables unloading mode. Every 100 sampels it unloades the model from the GPU to avoid carshing.")


args = parser.parse_args()

# %%
# Set up the wandb run 
#run = wandb.init(
#    entity="jacketdembys",
#    project=f"wacv-2025-{args.data}",
#    name="run_test_" + args.data+"-"+args.modelname+"-"+args.subset
#)

# %%
# Create a result folder
print(args.results_dir)
if not os.path.exists(args.results_dir):
    os.makedirs(args.results_dir)
# Out:
# /mnt/jacket/WACV-2025-Workshop-ViGIR/results/proposed

# %%
# Load test set:
file_path = 'Testing_Set.json'
#file_path = 'Validation_Set.json'
with open(file_path, 'r') as file:
    data = json.load(file)

print('Number of Annotated GT Images: ', len(data.keys()))
data_keys_test = list(data.keys())
print('Number of Annotated GT Images (List): ', len(data_keys_test))
# Out:
# Number of Annotated GT Images:  311
# Number of Annotated GT Images (List):  311

# %%
# Load the images
# directory = '/root/home/data_jpg'
# tile_dict = defaultdict(list)

# for filename in os.listdir(directory):
#     if filename.endswith('.jpg'):
#         parts = filename.split('_')
#         tile_number = parts[4].split('.')[0]
#         tile_dict[tile_number].append(os.path.join(directory,filename))

# tile_dict = dict(tile_dict)

# print("Total number of tiles: {}".format(len(tile_dict.keys())))

# %%
# Load the images
directory = '/root/home/data'
tile_dict = defaultdict(list)

for filename in os.listdir(directory):
    if filename.endswith('.jpg'):
        parts = filename.split('_')
        tile_number = parts[2].split('.')[0]
        tile_dict[tile_number].append(os.path.join(directory,filename))

tile_dict = dict(tile_dict)

print("Total number of tiles: {}".format(len(tile_dict.keys())))
# Out:
# Total number of tiles: 900

# %%
tile_dict
# Out:
# {'100': ['/root/home/data/neg_collage_100.jpg'],
#  '1000': ['/root/home/data/neg_collage_1000.jpg'],
#  '1001': ['/root/home/data/neg_collage_1001.jpg'],
#  '1002': ['/root/home/data/neg_collage_1002.jpg'],
#  '1003': ['/root/home/data/neg_collage_1003.jpg'],
#  '1004': ['/root/home/data/neg_collage_1004.jpg'],
#  '1005': ['/root/home/data/neg_collage_1005.jpg'],
#  '1006': ['/root/home/data/neg_collage_1006.jpg'],
#  '1007': ['/root/home/data/neg_collage_1007.jpg'],
#  '1009': ['/root/home/data/neg_collage_1009.jpg'],
#  '101': ['/root/home/data/neg_collage_101.jpg'],
#  '1010': ['/root/home/data/neg_collage_1010.jpg'],
#  '1011': ['/root/home/data/neg_collage_1011.jpg'],
#  '1013': ['/root/home/data/neg_collage_1013.jpg'],
#  '1014': ['/root/home/data/neg_collage_1014.jpg'],
#  '1015': ['/root/home/data/neg_collage_1015.jpg'],
#  '1017': ['/root/home/data/neg_collage_1017.jpg'],
#  '1018': ['/root/home/data/neg_collage_1018.jpg'],
#  '1019': ['/root/home/data/neg_collage_1019.jpg'],
#  '102': ['/root/home/data/neg_collage_102.jpg'],
#  '1020': ['/root/home/data/neg_collage_1020.jpg'],
#  '1021': ['/root/home/data/neg_collage_1021.jpg'],
#  '1022': ['/root/home/data/neg_collage_1022.jpg'],
#  '1023': ['/root/home/data/neg_collage_1023.jpg'],
#  '1024': ['/root/home/data/neg_collage_1024.jpg'],
#  '1025': ['/root/home/data/neg_collage_1025.jpg'],
#  '1027': ['/root/home/data/neg_collage_1027.jpg'],
#  '1028': ['/root/home/data/neg_collage_1028.jpg'],
#  '1029': ['/root/home/data/neg_collage_1029.jpg'],
#  '103': ['/root/home/data/neg_collage_103.jpg'],
#  '1030': ['/root/home/data/neg_collage_1030.jpg'],
#  '1031': ['/root/home/data/neg_collage_1031.jpg'],
#  '1032': ['/root/home/data/neg_collage_1032.jpg'],
#  '1033': ['/root/home/data/neg_collage_1033.jpg'],
#  '1034': ['/root/home/data/neg_collage_1034.jpg'],
#  '1035': ['/root/home/data/neg_collage_1035.jpg'],
#  '1036': ['/root/home/data/neg_collage_1036.jpg'],
#  '1037': ['/root/home/data/neg_collage_1037.jpg'],
#  '1038': ['/root/home/data/neg_collage_1038.jpg'],
#  '1039': ['/root/home/data/neg_collage_1039.jpg'],
#  '104': ['/root/home/data/neg_collage_104.jpg'],
#  '1040': ['/root/home/data/neg_collage_1040.jpg'],
#  '1041': ['/root/home/data/neg_collage_1041.jpg'],
#  '1042': ['/root/home/data/neg_collage_1042.jpg'],
#  '1043': ['/root/home/data/neg_collage_1043.jpg'],
#  '1044': ['/root/home/data/neg_collage_1044.jpg'],
#  '1045': ['/root/home/data/neg_collage_1045.jpg'],
#  '1046': ['/root/home/data/neg_collage_1046.jpg'],
#  '1047': ['/root/home/data/neg_collage_1047.jpg'],
#  '1049': ['/root/home/data/neg_collage_1049.jpg'],
#  '105': ['/root/home/data/neg_collage_105.jpg'],
#  '1050': ['/root/home/data/neg_collage_1050.jpg'],
#  '1051': ['/root/home/data/neg_collage_1051.jpg'],
#  '1052': ['/root/home/data/neg_collage_1052.jpg'],
#  '1053': ['/root/home/data/neg_collage_1053.jpg'],
#  '1054': ['/root/home/data/neg_collage_1054.jpg'],
#  '1056': ['/root/home/data/neg_collage_1056.jpg'],
#  '1057': ['/root/home/data/neg_collage_1057.jpg'],
#  '1058': ['/root/home/data/neg_collage_1058.jpg'],
#  '1059': ['/root/home/data/neg_collage_1059.jpg'],
#  '106': ['/root/home/data/neg_collage_106.jpg'],
#  '1061': ['/root/home/data/neg_collage_1061.jpg'],
#  '1062': ['/root/home/data/neg_collage_1062.jpg'],
#  '1063': ['/root/home/data/neg_collage_1063.jpg'],
#  '1064': ['/root/home/data/neg_collage_1064.jpg'],
#  '1065': ['/root/home/data/neg_collage_1065.jpg'],
#  '1067': ['/root/home/data/neg_collage_1067.jpg'],
#  '1068': ['/root/home/data/neg_collage_1068.jpg'],
#  '107': ['/root/home/data/neg_collage_107.jpg'],
#  '1070': ['/root/home/data/neg_collage_1070.jpg'],
#  '1071': ['/root/home/data/neg_collage_1071.jpg'],
#  '1072': ['/root/home/data/neg_collage_1072.jpg'],
#  '1073': ['/root/home/data/neg_collage_1073.jpg'],
#  '1074': ['/root/home/data/neg_collage_1074.jpg'],
#  '1075': ['/root/home/data/neg_collage_1075.jpg'],
#  '1076': ['/root/home/data/neg_collage_1076.jpg'],
#  '1077': ['/root/home/data/neg_collage_1077.jpg'],
#  '1078': ['/root/home/data/neg_collage_1078.jpg'],
#  '1079': ['/root/home/data/neg_collage_1079.jpg'],
#  '108': ['/root/home/data/neg_collage_108.jpg'],
#  '1080': ['/root/home/data/neg_collage_1080.jpg'],
#  '1081': ['/root/home/data/neg_collage_1081.jpg'],
#  '1083': ['/root/home/data/neg_collage_1083.jpg'],
#  '1084': ['/root/home/data/neg_collage_1084.jpg'],
#  '1085': ['/root/home/data/neg_collage_1085.jpg'],
#  '1086': ['/root/home/data/neg_collage_1086.jpg'],
#  '1087': ['/root/home/data/neg_collage_1087.jpg'],
#  '1088': ['/root/home/data/neg_collage_1088.jpg'],
#  '1089': ['/root/home/data/neg_collage_1089.jpg'],
#  '1092': ['/root/home/data/neg_collage_1092.jpg'],
#  '1094': ['/root/home/data/neg_collage_1094.jpg'],
#  '1095': ['/root/home/data/neg_collage_1095.jpg'],
#  '1096': ['/root/home/data/neg_collage_1096.jpg'],
#  '1097': ['/root/home/data/neg_collage_1097.jpg'],
#  '1098': ['/root/home/data/neg_collage_1098.jpg'],
#  '1099': ['/root/home/data/neg_collage_1099.jpg'],
#  '110': ['/root/home/data/neg_collage_110.jpg'],
#  '1100': ['/root/home/data/neg_collage_1100.jpg'],
#  '1102': ['/root/home/data/neg_collage_1102.jpg'],
#  '1104': ['/root/home/data/neg_collage_1104.jpg'],
#  '1105': ['/root/home/data/neg_collage_1105.jpg'],
#  '1106': ['/root/home/data/neg_collage_1106.jpg'],
#  '1107': ['/root/home/data/neg_collage_1107.jpg'],
#  '1108': ['/root/home/data/neg_collage_1108.jpg'],
#  '111': ['/root/home/data/neg_collage_111.jpg'],
#  '1110': ['/root/home/data/neg_collage_1110.jpg'],
#  '1111': ['/root/home/data/neg_collage_1111.jpg'],
#  '1112': ['/root/home/data/neg_collage_1112.jpg'],
#  '1113': ['/root/home/data/neg_collage_1113.jpg'],
#  '1114': ['/root/home/data/neg_collage_1114.jpg'],
#  '1115': ['/root/home/data/neg_collage_1115.jpg'],
#  '1116': ['/root/home/data/neg_collage_1116.jpg'],
#  '1117': ['/root/home/data/neg_collage_1117.jpg'],
#  '1118': ['/root/home/data/neg_collage_1118.jpg'],
#  '1121': ['/root/home/data/neg_collage_1121.jpg'],
#  '1122': ['/root/home/data/neg_collage_1122.jpg'],
#  '1123': ['/root/home/data/neg_collage_1123.jpg'],
#  '1124': ['/root/home/data/neg_collage_1124.jpg'],
#  '1125': ['/root/home/data/neg_collage_1125.jpg'],
#  '1127': ['/root/home/data/neg_collage_1127.jpg'],
#  '1128': ['/root/home/data/neg_collage_1128.jpg'],
#  '1129': ['/root/home/data/neg_collage_1129.jpg'],
#  '1130': ['/root/home/data/neg_collage_1130.jpg'],
#  '1132': ['/root/home/data/neg_collage_1132.jpg'],
#  '1133': ['/root/home/data/neg_collage_1133.jpg'],
#  '1134': ['/root/home/data/neg_collage_1134.jpg'],
#  '1135': ['/root/home/data/neg_collage_1135.jpg'],
#  '1137': ['/root/home/data/neg_collage_1137.jpg'],
#  '1138': ['/root/home/data/neg_collage_1138.jpg'],
#  '114': ['/root/home/data/neg_collage_114.jpg'],
#  '1140': ['/root/home/data/neg_collage_1140.jpg'],
#  '1141': ['/root/home/data/neg_collage_1141.jpg'],
#  '1142': ['/root/home/data/neg_collage_1142.jpg'],
#  '1143': ['/root/home/data/neg_collage_1143.jpg'],
#  '1145': ['/root/home/data/neg_collage_1145.jpg'],
#  '1146': ['/root/home/data/neg_collage_1146.jpg'],
#  '1147': ['/root/home/data/neg_collage_1147.jpg'],
#  '1148': ['/root/home/data/neg_collage_1148.jpg'],
#  '1149': ['/root/home/data/neg_collage_1149.jpg'],
#  '115': ['/root/home/data/neg_collage_115.jpg'],
#  '1150': ['/root/home/data/neg_collage_1150.jpg'],
#  '116': ['/root/home/data/neg_collage_116.jpg'],
#  '117': ['/root/home/data/neg_collage_117.jpg'],
#  '118': ['/root/home/data/neg_collage_118.jpg'],
#  '119': ['/root/home/data/neg_collage_119.jpg'],
#  '120': ['/root/home/data/neg_collage_120.jpg'],
#  '121': ['/root/home/data/neg_collage_121.jpg'],
#  '123': ['/root/home/data/neg_collage_123.jpg'],
#  '124': ['/root/home/data/neg_collage_124.jpg'],
#  '125': ['/root/home/data/neg_collage_125.jpg'],
#  '126': ['/root/home/data/neg_collage_126.jpg'],
#  '127': ['/root/home/data/neg_collage_127.jpg'],
#  '128': ['/root/home/data/neg_collage_128.jpg'],
#  '129': ['/root/home/data/neg_collage_129.jpg'],
#  '130': ['/root/home/data/neg_collage_130.jpg'],
#  '131': ['/root/home/data/neg_collage_131.jpg'],
#  '132': ['/root/home/data/neg_collage_132.jpg'],
#  '134': ['/root/home/data/neg_collage_134.jpg'],
#  '135': ['/root/home/data/neg_collage_135.jpg'],
#  '248': ['/root/home/data/neg_collage_248.jpg'],
#  '249': ['/root/home/data/neg_collage_249.jpg'],
#  '250': ['/root/home/data/neg_collage_250.jpg'],
#  '251': ['/root/home/data/neg_collage_251.jpg'],
#  '252': ['/root/home/data/neg_collage_252.jpg'],
#  '253': ['/root/home/data/neg_collage_253.jpg'],
#  '254': ['/root/home/data/neg_collage_254.jpg'],
#  '255': ['/root/home/data/neg_collage_255.jpg'],
#  '256': ['/root/home/data/neg_collage_256.jpg'],
#  '257': ['/root/home/data/neg_collage_257.jpg'],
#  '259': ['/root/home/data/neg_collage_259.jpg'],
#  '260': ['/root/home/data/neg_collage_260.jpg'],
#  '261': ['/root/home/data/neg_collage_261.jpg'],
#  '263': ['/root/home/data/neg_collage_263.jpg'],
#  '264': ['/root/home/data/neg_collage_264.jpg'],
#  '265': ['/root/home/data/neg_collage_265.jpg'],
#  '266': ['/root/home/data/neg_collage_266.jpg'],
#  '267': ['/root/home/data/neg_collage_267.jpg'],
#  '268': ['/root/home/data/neg_collage_268.jpg'],
#  '269': ['/root/home/data/neg_collage_269.jpg'],
#  '270': ['/root/home/data/neg_collage_270.jpg'],
#  '271': ['/root/home/data/neg_collage_271.jpg'],
#  '272': ['/root/home/data/neg_collage_272.jpg'],
#  '273': ['/root/home/data/neg_collage_273.jpg'],
#  '274': ['/root/home/data/neg_collage_274.jpg'],
#  '276': ['/root/home/data/neg_collage_276.jpg'],
#  '277': ['/root/home/data/neg_collage_277.jpg'],
#  '279': ['/root/home/data/neg_collage_279.jpg'],
#  '281': ['/root/home/data/neg_collage_281.jpg'],
#  '282': ['/root/home/data/neg_collage_282.jpg'],
#  '283': ['/root/home/data/neg_collage_283.jpg'],
#  '285': ['/root/home/data/neg_collage_285.jpg'],
#  '286': ['/root/home/data/neg_collage_286.jpg'],
#  '287': ['/root/home/data/neg_collage_287.jpg'],
#  '288': ['/root/home/data/neg_collage_288.jpg'],
#  '289': ['/root/home/data/neg_collage_289.jpg'],
#  '290': ['/root/home/data/neg_collage_290.jpg'],
#  '291': ['/root/home/data/neg_collage_291.jpg'],
#  '292': ['/root/home/data/neg_collage_292.jpg'],
#  '293': ['/root/home/data/neg_collage_293.jpg'],
#  '294': ['/root/home/data/neg_collage_294.jpg'],
#  '295': ['/root/home/data/neg_collage_295.jpg'],
#  '296': ['/root/home/data/neg_collage_296.jpg'],
#  '297': ['/root/home/data/neg_collage_297.jpg'],
#  '298': ['/root/home/data/neg_collage_298.jpg'],
#  '299': ['/root/home/data/neg_collage_299.jpg'],
#  '300': ['/root/home/data/neg_collage_300.jpg'],
#  '301': ['/root/home/data/neg_collage_301.jpg'],
#  '302': ['/root/home/data/neg_collage_302.jpg'],
#  '303': ['/root/home/data/neg_collage_303.jpg'],
#  '304': ['/root/home/data/neg_collage_304.jpg'],
#  '305': ['/root/home/data/neg_collage_305.jpg'],
#  '306': ['/root/home/data/neg_collage_306.jpg'],
#  '307': ['/root/home/data/neg_collage_307.jpg'],
#  '308': ['/root/home/data/neg_collage_308.jpg'],
#  '309': ['/root/home/data/neg_collage_309.jpg'],
#  '310': ['/root/home/data/neg_collage_310.jpg'],
#  '311': ['/root/home/data/neg_collage_311.jpg'],
#  '312': ['/root/home/data/neg_collage_312.jpg'],
#  '313': ['/root/home/data/neg_collage_313.jpg'],
#  '314': ['/root/home/data/neg_collage_314.jpg'],
#  '315': ['/root/home/data/neg_collage_315.jpg'],
#  '316': ['/root/home/data/neg_collage_316.jpg'],
#  '317': ['/root/home/data/neg_collage_317.jpg'],
#  '319': ['/root/home/data/neg_collage_319.jpg'],
#  '320': ['/root/home/data/neg_collage_320.jpg'],
#  '322': ['/root/home/data/neg_collage_322.jpg'],
#  '323': ['/root/home/data/neg_collage_323.jpg'],
#  '324': ['/root/home/data/neg_collage_324.jpg'],
#  '325': ['/root/home/data/neg_collage_325.jpg'],
#  '326': ['/root/home/data/neg_collage_326.jpg'],
#  '327': ['/root/home/data/neg_collage_327.jpg'],
#  '328': ['/root/home/data/neg_collage_328.jpg'],
#  '329': ['/root/home/data/neg_collage_329.jpg'],
#  '330': ['/root/home/data/neg_collage_330.jpg'],
#  '331': ['/root/home/data/neg_collage_331.jpg'],
#  '332': ['/root/home/data/neg_collage_332.jpg'],
#  '334': ['/root/home/data/neg_collage_334.jpg'],
#  '335': ['/root/home/data/neg_collage_335.jpg'],
#  '336': ['/root/home/data/neg_collage_336.jpg'],
#  '337': ['/root/home/data/neg_collage_337.jpg'],
#  '338': ['/root/home/data/neg_collage_338.jpg'],
#  '339': ['/root/home/data/neg_collage_339.jpg'],
#  '341': ['/root/home/data/neg_collage_341.jpg'],
#  '343': ['/root/home/data/neg_collage_343.jpg'],
#  '344': ['/root/home/data/neg_collage_344.jpg'],
#  '345': ['/root/home/data/neg_collage_345.jpg'],
#  '346': ['/root/home/data/neg_collage_346.jpg'],
#  '347': ['/root/home/data/neg_collage_347.jpg'],
#  '348': ['/root/home/data/neg_collage_348.jpg'],
#  '452': ['/root/home/data/neg_collage_452.jpg'],
#  '453': ['/root/home/data/neg_collage_453.jpg'],
#  '454': ['/root/home/data/neg_collage_454.jpg'],
#  '456': ['/root/home/data/neg_collage_456.jpg'],
#  '457': ['/root/home/data/neg_collage_457.jpg'],
#  '458': ['/root/home/data/neg_collage_458.jpg'],
#  '461': ['/root/home/data/neg_collage_461.jpg'],
#  '462': ['/root/home/data/neg_collage_462.jpg'],
#  '463': ['/root/home/data/neg_collage_463.jpg'],
#  '464': ['/root/home/data/neg_collage_464.jpg'],
#  '466': ['/root/home/data/neg_collage_466.jpg'],
#  '467': ['/root/home/data/neg_collage_467.jpg'],
#  '468': ['/root/home/data/neg_collage_468.jpg'],
#  '469': ['/root/home/data/neg_collage_469.jpg'],
#  '470': ['/root/home/data/neg_collage_470.jpg'],
#  '471': ['/root/home/data/neg_collage_471.jpg'],
#  '472': ['/root/home/data/neg_collage_472.jpg'],
#  '473': ['/root/home/data/neg_collage_473.jpg'],
#  '474': ['/root/home/data/neg_collage_474.jpg'],
#  '475': ['/root/home/data/neg_collage_475.jpg'],
#  '476': ['/root/home/data/neg_collage_476.jpg'],
#  '478': ['/root/home/data/neg_collage_478.jpg'],
#  '479': ['/root/home/data/neg_collage_479.jpg'],
#  '480': ['/root/home/data/neg_collage_480.jpg'],
#  '481': ['/root/home/data/neg_collage_481.jpg'],
#  '482': ['/root/home/data/neg_collage_482.jpg'],
#  '483': ['/root/home/data/neg_collage_483.jpg'],
#  '484': ['/root/home/data/neg_collage_484.jpg'],
#  '485': ['/root/home/data/neg_collage_485.jpg'],
#  '486': ['/root/home/data/neg_collage_486.jpg'],
#  '487': ['/root/home/data/neg_collage_487.jpg'],
#  '489': ['/root/home/data/neg_collage_489.jpg'],
#  '490': ['/root/home/data/neg_collage_490.jpg'],
#  '491': ['/root/home/data/neg_collage_491.jpg'],
#  '492': ['/root/home/data/neg_collage_492.jpg'],
#  '493': ['/root/home/data/neg_collage_493.jpg'],
#  '494': ['/root/home/data/neg_collage_494.jpg'],
#  '495': ['/root/home/data/neg_collage_495.jpg'],
#  '496': ['/root/home/data/neg_collage_496.jpg'],
#  '497': ['/root/home/data/neg_collage_497.jpg'],
#  '498': ['/root/home/data/neg_collage_498.jpg'],
#  '500': ['/root/home/data/neg_collage_500.jpg'],
#  '501': ['/root/home/data/neg_collage_501.jpg'],
#  '502': ['/root/home/data/neg_collage_502.jpg'],
#  '504': ['/root/home/data/neg_collage_504.jpg'],
#  '505': ['/root/home/data/neg_collage_505.jpg'],
#  '507': ['/root/home/data/neg_collage_507.jpg'],
#  '509': ['/root/home/data/neg_collage_509.jpg'],
#  '510': ['/root/home/data/neg_collage_510.jpg'],
#  '511': ['/root/home/data/neg_collage_511.jpg'],
#  '512': ['/root/home/data/neg_collage_512.jpg'],
#  '513': ['/root/home/data/neg_collage_513.jpg'],
#  '515': ['/root/home/data/neg_collage_515.jpg'],
#  '516': ['/root/home/data/neg_collage_516.jpg'],
#  '517': ['/root/home/data/neg_collage_517.jpg'],
#  '518': ['/root/home/data/neg_collage_518.jpg'],
#  '519': ['/root/home/data/neg_collage_519.jpg'],
#  '520': ['/root/home/data/neg_collage_520.jpg'],
#  '521': ['/root/home/data/neg_collage_521.jpg'],
#  '522': ['/root/home/data/neg_collage_522.jpg'],
#  '524': ['/root/home/data/neg_collage_524.jpg'],
#  '525': ['/root/home/data/neg_collage_525.jpg'],
#  '526': ['/root/home/data/neg_collage_526.jpg'],
#  '527': ['/root/home/data/neg_collage_527.jpg'],
#  '528': ['/root/home/data/neg_collage_528.jpg'],
#  '529': ['/root/home/data/neg_collage_529.jpg'],
#  '530': ['/root/home/data/neg_collage_530.jpg'],
#  '531': ['/root/home/data/neg_collage_531.jpg'],
#  '532': ['/root/home/data/neg_collage_532.jpg'],
#  '69': ['/root/home/data/neg_collage_69.jpg'],
#  '70': ['/root/home/data/neg_collage_70.jpg'],
#  '71': ['/root/home/data/neg_collage_71.jpg'],
#  '73': ['/root/home/data/neg_collage_73.jpg'],
#  '732': ['/root/home/data/neg_collage_732.jpg'],
#  '733': ['/root/home/data/neg_collage_733.jpg'],
#  '734': ['/root/home/data/neg_collage_734.jpg'],
#  '735': ['/root/home/data/neg_collage_735.jpg'],
#  '736': ['/root/home/data/neg_collage_736.jpg'],
#  '737': ['/root/home/data/neg_collage_737.jpg'],
#  '739': ['/root/home/data/neg_collage_739.jpg'],
#  '74': ['/root/home/data/neg_collage_74.jpg'],
#  '740': ['/root/home/data/neg_collage_740.jpg'],
#  '741': ['/root/home/data/neg_collage_741.jpg'],
#  '742': ['/root/home/data/neg_collage_742.jpg'],
#  '743': ['/root/home/data/neg_collage_743.jpg'],
#  '744': ['/root/home/data/neg_collage_744.jpg'],
#  '745': ['/root/home/data/neg_collage_745.jpg'],
#  '746': ['/root/home/data/neg_collage_746.jpg'],
#  '747': ['/root/home/data/neg_collage_747.jpg'],
#  '748': ['/root/home/data/neg_collage_748.jpg'],
#  '749': ['/root/home/data/neg_collage_749.jpg'],
#  '75': ['/root/home/data/neg_collage_75.jpg'],
#  '750': ['/root/home/data/neg_collage_750.jpg'],
#  '751': ['/root/home/data/neg_collage_751.jpg'],
#  '752': ['/root/home/data/neg_collage_752.jpg'],
#  '753': ['/root/home/data/neg_collage_753.jpg'],
#  '754': ['/root/home/data/neg_collage_754.jpg'],
#  '755': ['/root/home/data/neg_collage_755.jpg'],
#  '756': ['/root/home/data/neg_collage_756.jpg'],
#  '757': ['/root/home/data/neg_collage_757.jpg'],
#  '758': ['/root/home/data/neg_collage_758.jpg'],
#  '759': ['/root/home/data/neg_collage_759.jpg'],
#  '76': ['/root/home/data/neg_collage_76.jpg'],
#  '760': ['/root/home/data/neg_collage_760.jpg'],
#  '761': ['/root/home/data/neg_collage_761.jpg'],
#  '763': ['/root/home/data/neg_collage_763.jpg'],
#  '764': ['/root/home/data/neg_collage_764.jpg'],
#  '765': ['/root/home/data/neg_collage_765.jpg'],
#  '766': ['/root/home/data/neg_collage_766.jpg'],
#  '767': ['/root/home/data/neg_collage_767.jpg'],
#  '768': ['/root/home/data/neg_collage_768.jpg'],
#  '769': ['/root/home/data/neg_collage_769.jpg'],
#  '77': ['/root/home/data/neg_collage_77.jpg'],
#  '770': ['/root/home/data/neg_collage_770.jpg'],
#  '771': ['/root/home/data/neg_collage_771.jpg'],
#  '772': ['/root/home/data/neg_collage_772.jpg'],
#  '773': ['/root/home/data/neg_collage_773.jpg'],
#  '774': ['/root/home/data/neg_collage_774.jpg'],
#  '776': ['/root/home/data/neg_collage_776.jpg'],
#  '777': ['/root/home/data/neg_collage_777.jpg'],
#  '778': ['/root/home/data/neg_collage_778.jpg'],
#  '779': ['/root/home/data/neg_collage_779.jpg'],
#  '78': ['/root/home/data/neg_collage_78.jpg'],
#  '780': ['/root/home/data/neg_collage_780.jpg'],
#  '782': ['/root/home/data/neg_collage_782.jpg'],
#  '783': ['/root/home/data/neg_collage_783.jpg'],
#  '784': ['/root/home/data/neg_collage_784.jpg'],
#  '786': ['/root/home/data/neg_collage_786.jpg'],
#  '787': ['/root/home/data/neg_collage_787.jpg'],
#  '788': ['/root/home/data/neg_collage_788.jpg'],
#  '789': ['/root/home/data/neg_collage_789.jpg'],
#  '79': ['/root/home/data/neg_collage_79.jpg'],
#  '790': ['/root/home/data/neg_collage_790.jpg'],
#  '793': ['/root/home/data/neg_collage_793.jpg'],
#  '794': ['/root/home/data/neg_collage_794.jpg'],
#  '795': ['/root/home/data/neg_collage_795.jpg'],
#  '796': ['/root/home/data/neg_collage_796.jpg'],
#  '797': ['/root/home/data/neg_collage_797.jpg'],
#  '798': ['/root/home/data/neg_collage_798.jpg'],
#  '80': ['/root/home/data/neg_collage_80.jpg'],
#  '801': ['/root/home/data/neg_collage_801.jpg'],
#  '803': ['/root/home/data/neg_collage_803.jpg'],
#  '804': ['/root/home/data/neg_collage_804.jpg'],
#  '805': ['/root/home/data/neg_collage_805.jpg'],
#  '806': ['/root/home/data/neg_collage_806.jpg'],
#  '807': ['/root/home/data/neg_collage_807.jpg'],
#  '808': ['/root/home/data/neg_collage_808.jpg'],
#  '809': ['/root/home/data/neg_collage_809.jpg'],
#  '81': ['/root/home/data/neg_collage_81.jpg'],
#  '810': ['/root/home/data/neg_collage_810.jpg'],
#  '812': ['/root/home/data/neg_collage_812.jpg'],
#  '813': ['/root/home/data/neg_collage_813.jpg'],
#  '815': ['/root/home/data/neg_collage_815.jpg'],
#  '816': ['/root/home/data/neg_collage_816.jpg'],
#  '818': ['/root/home/data/neg_collage_818.jpg'],
#  '819': ['/root/home/data/neg_collage_819.jpg'],
#  '82': ['/root/home/data/neg_collage_82.jpg'],
#  '820': ['/root/home/data/neg_collage_820.jpg'],
#  '821': ['/root/home/data/neg_collage_821.jpg'],
#  '822': ['/root/home/data/neg_collage_822.jpg'],
#  '823': ['/root/home/data/neg_collage_823.jpg'],
#  '826': ['/root/home/data/neg_collage_826.jpg'],
#  '828': ['/root/home/data/neg_collage_828.jpg'],
#  '829': ['/root/home/data/neg_collage_829.jpg'],
#  '83': ['/root/home/data/neg_collage_83.jpg'],
#  '830': ['/root/home/data/neg_collage_830.jpg'],
#  '831': ['/root/home/data/neg_collage_831.jpg'],
#  '832': ['/root/home/data/neg_collage_832.jpg'],
#  '834': ['/root/home/data/neg_collage_834.jpg'],
#  '835': ['/root/home/data/neg_collage_835.jpg'],
#  '836': ['/root/home/data/neg_collage_836.jpg'],
#  '837': ['/root/home/data/neg_collage_837.jpg'],
#  '838': ['/root/home/data/neg_collage_838.jpg'],
#  '839': ['/root/home/data/neg_collage_839.jpg'],
#  '84': ['/root/home/data/neg_collage_84.jpg'],
#  '840': ['/root/home/data/neg_collage_840.jpg'],
#  '841': ['/root/home/data/neg_collage_841.jpg'],
#  '842': ['/root/home/data/neg_collage_842.jpg'],
#  '843': ['/root/home/data/neg_collage_843.jpg'],
#  '844': ['/root/home/data/neg_collage_844.jpg'],
#  '846': ['/root/home/data/neg_collage_846.jpg'],
#  '847': ['/root/home/data/neg_collage_847.jpg'],
#  '848': ['/root/home/data/neg_collage_848.jpg'],
#  '849': ['/root/home/data/neg_collage_849.jpg'],
#  '85': ['/root/home/data/neg_collage_85.jpg'],
#  '86': ['/root/home/data/neg_collage_86.jpg'],
#  '87': ['/root/home/data/neg_collage_87.jpg'],
#  '88': ['/root/home/data/neg_collage_88.jpg'],
#  '89': ['/root/home/data/neg_collage_89.jpg'],
#  '90': ['/root/home/data/neg_collage_90.jpg'],
#  '91': ['/root/home/data/neg_collage_91.jpg'],
#  '92': ['/root/home/data/neg_collage_92.jpg'],
#  '93': ['/root/home/data/neg_collage_93.jpg'],
#  '94': ['/root/home/data/neg_collage_94.jpg'],
#  '95': ['/root/home/data/neg_collage_95.jpg'],
#  '96': ['/root/home/data/neg_collage_96.jpg'],
#  '97': ['/root/home/data/neg_collage_97.jpg'],
#  '98': ['/root/home/data/neg_collage_98.jpg'],
#  '99': ['/root/home/data/neg_collage_99.jpg'],
#  '998': ['/root/home/data/neg_collage_998.jpg'],
#  '999': ['/root/home/data/neg_collage_999.jpg'],
#  '0': ['/root/home/data/pos_collage_0.jpg'],
#  '1': ['/root/home/data/pos_collage_1.jpg'],
#  '10': ['/root/home/data/pos_collage_10.jpg'],
#  '11': ['/root/home/data/pos_collage_11.jpg'],
#  '12': ['/root/home/data/pos_collage_12.jpg'],
#  '136': ['/root/home/data/pos_collage_136.jpg'],
#  '137': ['/root/home/data/pos_collage_137.jpg'],
#  '139': ['/root/home/data/pos_collage_139.jpg'],
#  '14': ['/root/home/data/pos_collage_14.jpg'],
#  '140': ['/root/home/data/pos_collage_140.jpg'],
#  '141': ['/root/home/data/pos_collage_141.jpg'],
#  '142': ['/root/home/data/pos_collage_142.jpg'],
#  '143': ['/root/home/data/pos_collage_143.jpg'],
#  '144': ['/root/home/data/pos_collage_144.jpg'],
#  '145': ['/root/home/data/pos_collage_145.jpg'],
#  '148': ['/root/home/data/pos_collage_148.jpg'],
#  '149': ['/root/home/data/pos_collage_149.jpg'],
#  '150': ['/root/home/data/pos_collage_150.jpg'],
#  '153': ['/root/home/data/pos_collage_153.jpg'],
#  '154': ['/root/home/data/pos_collage_154.jpg'],
#  '155': ['/root/home/data/pos_collage_155.jpg'],
#  '156': ['/root/home/data/pos_collage_156.jpg'],
#  '157': ['/root/home/data/pos_collage_157.jpg'],
#  '158': ['/root/home/data/pos_collage_158.jpg'],
#  '16': ['/root/home/data/pos_collage_16.jpg'],
#  '160': ['/root/home/data/pos_collage_160.jpg'],
#  '162': ['/root/home/data/pos_collage_162.jpg'],
#  '163': ['/root/home/data/pos_collage_163.jpg'],
#  '164': ['/root/home/data/pos_collage_164.jpg'],
#  '165': ['/root/home/data/pos_collage_165.jpg'],
#  '166': ['/root/home/data/pos_collage_166.jpg'],
#  '937': ['/root/home/data/pos_collage_937.jpg'],
#  '938': ['/root/home/data/pos_collage_938.jpg'],
#  '941': ['/root/home/data/pos_collage_941.jpg'],
#  '942': ['/root/home/data/pos_collage_942.jpg'],
#  '943': ['/root/home/data/pos_collage_943.jpg'],
#  '944': ['/root/home/data/pos_collage_944.jpg'],
#  '945': ['/root/home/data/pos_collage_945.jpg'],
#  '946': ['/root/home/data/pos_collage_946.jpg'],
#  '947': ['/root/home/data/pos_collage_947.jpg'],
#  '948': ['/root/home/data/pos_collage_948.jpg'],
#  '949': ['/root/home/data/pos_collage_949.jpg'],
#  '950': ['/root/home/data/pos_collage_950.jpg'],
#  '951': ['/root/home/data/pos_collage_951.jpg'],
#  '952': ['/root/home/data/pos_collage_952.jpg'],
#  '953': ['/root/home/data/pos_collage_953.jpg'],
#  '955': ['/root/home/data/pos_collage_955.jpg'],
#  '956': ['/root/home/data/pos_collage_956.jpg'],
#  '958': ['/root/home/data/pos_collage_958.jpg'],
#  '962': ['/root/home/data/pos_collage_962.jpg'],
#  '965': ['/root/home/data/pos_collage_965.jpg'],
#  '966': ['/root/home/data/pos_collage_966.jpg'],
#  '967': ['/root/home/data/pos_collage_967.jpg'],
#  '968': ['/root/home/data/pos_collage_968.jpg'],
#  '972': ['/root/home/data/pos_collage_972.jpg'],
#  '973': ['/root/home/data/pos_collage_973.jpg'],
#  '975': ['/root/home/data/pos_collage_975.jpg'],
#  '976': ['/root/home/data/pos_collage_976.jpg'],
#  '977': ['/root/home/data/pos_collage_977.jpg'],
#  '978': ['/root/home/data/pos_collage_978.jpg'],
#  '979': ['/root/home/data/pos_collage_979.jpg'],
#  '980': ['/root/home/data/pos_collage_980.jpg'],
#  '982': ['/root/home/data/pos_collage_982.jpg'],
#  '984': ['/root/home/data/pos_collage_984.jpg'],
#  '988': ['/root/home/data/pos_collage_988.jpg'],
#  '991': ['/root/home/data/pos_collage_991.jpg'],
#  '992': ['/root/home/data/pos_collage_992.jpg'],
#  '993': ['/root/home/data/pos_collage_993.jpg'],
#  '995': ['/root/home/data/pos_collage_995.jpg'],
#  '996': ['/root/home/data/pos_collage_996.jpg'],
#  '997': ['/root/home/data/pos_collage_997.jpg']}

# %%
#for tile_number, file_list in tile_dict.items():
#    tile_dict[tile_number] = sorted(file_list, key=lambda x: int(x.split('_')[3]))

# %%
tile_dict_val = {}
for tile_number, file_list in tile_dict.items():
    if tile_number in data_keys_test:
        #tile_dict[tile_number] = sorted(file_list, key=lambda x: int(x.split('_')[2]))
        tile_dict_val[tile_number] = file_list

# %%
#unwanted_patterns = ['rgb_0', 'rgb_2', 'rgb_4']

# %%
#data = {key: [path for path in paths if not any(sub in path for sub in unwanted_patterns)] 
#        for key, paths in tile_dict.items()}

# %%
data = copy.deepcopy(tile_dict_val)
print('Number of collage in set: ', len(tile_dict_val))
# Out:
# Number of collage in set:  311

# %%
print(data)
# Out:
['/root/home/data/neg_collage_253.jpg'], '266': ['/root/home/data/neg_collage_266.jpg'], '267': ['/root/home/data/neg_collage_267.jpg'], '272': ['/root/home/data/neg_collage_272.jpg'], '273': ['/root/home/data/neg_collage_273.jpg'], '287': ['/root/home/data/neg_collage_287.jpg'], '288': ['/root/home/data/neg_collage_288.jpg'], '289': ['/root/home/data/neg_collage_289.jpg'], '301': ['/root/home/data/neg_collage_301.jpg'], '306': ['/root/home/data/neg_collage_306.jpg'], '310': ['/root/home/data/neg_collage_310.jpg'], '312': ['/root/home/data/neg_collage_312.jpg'], '316': ['/root/home/data/neg_collage_316.jpg'], '319': ['/root/home/data/neg_collage_319.jpg'], '320': ['/root/home/data/neg_collage_320.jpg'], '322': ['/root/home/data/neg_collage_322.jpg'], '331': ['/root/home/data/neg_collage_331.jpg'], '334': ['/root/home/data/neg_collage_334.jpg'], '335': ['/root/home/data/neg_collage_335.jpg'], '337': ['/root/home/data/neg_collage_337.jpg'], '343': ['/root/home/data/neg_collage_343.jpg'], '344': ['/root/home/data/neg_collage_344.jpg'], '454': ['/root/home/data/ne ...

# %%
"""
questions = [
    "Across the images, do you see a low point in the terrain where a temporary gully or depression begins to form without a permanent water feature? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Do narrow, winding paths or channels appear and become more defined across the sequence? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Over time, do any linear depressions or ruts become more pronounced along natural drainage lines or slopes? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Does a narrow, shallow channel become visibly deeper or more indented into the soil over the image sequence? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Are there areas where soil appears disturbed or vegetation is removed, showing progression over the images? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Across the sequence, does a specific path lack vegetation, suggesting an evolving or emerging channel? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Does the texture of the soil appear to change, becoming coarser or showing small pebbles in areas that develop into channels? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Can you see any clear starting and ending points for these channels becoming more evident over time? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Do small rills or grooves indicating water flow appear or deepen across the images? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Is there a gradual exposure of lighter-colored soil as the gully forms? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Are there sediment accumulations forming at the lower ends of channels as time progresses? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Across the images, do signs of water activity, like soil clumps or crusting, appear or intensify in specific areas? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Do shallow side walls along the channel areas become more defined as the sequence progresses? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Do deposits of silt or small debris appear and accumulate along any emerging channel paths? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Can you observe branching patterns that resemble temporary streams forming or intensifying over time? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Do areas with compacted soil or minor slope collapse become more noticeable along the developing channel edges? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Are there indications of nearby human activity, such as tillage or machinery tracks, influencing the formation or expansion of these channels? Please answer with YES or NO Only. DO NOT mention the reason."
]
"""

#questions = ["Given a collage image of six distinct photos. How many distinct photos do you see in the provided collage image? Your answer should only include the number of photos and nothing else."]
#questions = ["Given a collage of six images. How many images do you see in the provided collage? Your answer should only include the number of photos and nothing else."]
#questions = ["Given this collage of six images. How many images do you see in the provided collage? Your output must just include the number of images and nothing else."]
#questions = ["Given this collage of six images of the exact same area, collected over a period of 10 years. Are there any ephemeral gully appearances? Answer by Yes or No and nothing else."]

#questions = ["Given this collage of six images of the exact same area, collected over a period of 10 years. Analyze these collages and provide a definitive conclusion without needing more information to the following question and not just a list of steps: \n Question: are there any ephemeral gully appearances by looking at all of them together? "]
#questions = ["Given this collage of six images of the exact same area, collected over a period of 10 years. Are there any ephemeral gully appearances by looking at all of them together?. Reason and conclude with only yes or no. "]
questions = ["Given this collage of six images of the exact same area, collected over a period of 10 years. Are there any ephemeral gully appearances by looking at all of them together?. Provide the reasons for your answer without needing more information."]

"""
questions = [
    "Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear?  Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent?  Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes?  Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil?  Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed?  Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Provide the reason.",
    "Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Provide the reason."
]
"""
# Out:
# '\nquestions = [\n    "Given these six images of the exact same area and collected over a period of 10 years, do you see a low point in the terrain? Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, do narrow, winding paths or channels appear?  Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there winding paths that become intermittent recurrent?  Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there any linear depressions or ruts which appear more pronounced along natural drainage lines or slopes?  Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there narrow and shallow channels which appear intermittently deeper or more indented into the soil?  Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there areas where soil appears disturbed or vegetation is removed?  Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, does a specific path lack vegetation, suggesting an evolving or emerging channel? Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there varying types and levels of coarseness in the texture of the soil? Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there clear starting and ending points of potential channels? Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there small rills or grooves indicating water flow? Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, is there a varying exposure of lighter or darker colored soil? Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there sediment accumulations forming? Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there signs of water activity, like soil clumps or crusting, that appear or intensify in specific areas? Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there any branching patterns that resemble temporary streams? Provide the reason.",\n    "Given these six images of the exact same area and collected over a period of 10 years, are there indications of nearby human activity, such as tillage or machinery tracks? Provide the reason."\n]\n'

# %%
model_name = args.modelname
ollama.pull(model_name)

timeout_duration = args.timeout

options= {  # new
            "seed": 123,
            "temperature": 0,
            "num_ctx": 2048, # must be set, otherwise slightly random output
        }

model_labels = {}
count = 0

# %%
count = 0
saving_response=dict(tile_dict_val.copy())

for key, info in tqdm(data.items()):

    #print(key)
    #print(info)
    
    count+=1
    for question in questions:
        response = ollama.generate(model=model_name, 
                                   prompt=question, 
                                   images=info, 
                                   options=options)
        saving_response[key].append(response['response'])
        print(response['response'])

        #sys.exit()
# Out:
#   0%|▎                                                                                                     | 1/311 [00:02<13:54,  2.69s/it]
# Based on the provided image alone and assuming that these are aerial photographs taken from satellites or drones with consistent parameters such as time, weather conditions, and camera settings, it is challenging to definitively identify ephemeral gully appearances across all six images due to several factors:
#
# 1. **Resolution Limitations**: The resolution of satellite imagery typically does not allow for the detailed observation of small-scale features like ephemeral gullies which are often transient or occur in areas with dense vegetation.
#
# 2. **Vegetation Cover**: Dense forest cover can obscure any underlying topographical changes, making it difficult to distinguish between natural landscape variations and human activities such as logging or land clearing that could create temporary gullies.
#
# 3. **Lighting Conditions**: Variations in lighting conditions (such as cloud cover) over the 10-year period might affect visibility of certain features within the forest canopy.
#
# 4. **Temporal Changes**: Ephemeral gullies are typically short-lived and may not be visible across all images if they have already dried up or been covered by new vegetation before a subsequent image was taken.
#
# 5. **Image Quality**: The quality of each photograph can vary, with some potentially being clearer than others due to factors like camera calibration, sensor sensitivity, or atmospheric conditions at the time of capture.
#
# Without additional information such as timestamps for when each photo was taken, specific geographic coordinates, and knowledge about local environmental changes (e.g., deforestation rates), it is not possible to conclusively determine if ephemeral gullies have appeared in these images. A more detailed analysis with higher-resolution imagery or ground-truth data would be necessary to make such a determination accurately.
#
# Therefore, based on the provided image alone and without additional context, we cannot definitively answer whether there are any ephemeral gully appearances across all six images collected over 10 years.
#   1%|▋                                                                                                     | 2/311 [00:04<09:54,  1.92s/it]
# Based on the provided image alone and assuming that each square represents an aerial view taken during different seasons or times of day, it is possible to infer some changes in the landscape over time. However, due to the limited resolution and lack of temporal context within a single frame, definitive conclusions about ephemeral gully appearances cannot be drawn.
#
# To accurately assess any transient features such as gullies, one would need more information on factors like soil moisture levels, vegetation cover, land use changes, or even weather patterns that could influence erosion. Without these additional data points and the ability to compare them over time within a single image set, it is not possible to conclusively identify ephemeral gully appearances in this collage.
#
# Therefore, while there might be subtle variations across the squares due to natural processes like seasonal shifts, without further context or higher-resolution imagery showing changes more clearly, any claims about transient features such as gullies would remain speculative.
#   1%|▉                                                                                                     | 3/311 [00:06<11:47,  2.30s/it]
# Based on the provided image alone and assuming that each square represents an aerial view taken during different seasons or times of day, it is possible to infer some changes in the landscape over time due to natural processes such as erosion.
#
# Ephemeral gullies are typically formed by water flow through a dry bed after rainfall. They can appear briefly but may not be visible at all other times when there's no runoff. By examining each image closely and comparing them, one might look for subtle changes in the land surface that could indicate past ephemeral gully formation.
#
# For instance:
# 1. The top left square shows a uniform green field with horizontal lines suggesting plowing or crop rows.
# 2. Moving clockwise through the squares, we see variations: some have darker patches which may be shadows from trees or different types of vegetation; others show more texture and color variation that could indicate soil composition differences.
#
# If there are any ephemeral gullies present in these images, they might appear as irregularities on the surface such as small depressions or lines where water has flowed through. However, without knowing when each photo was taken (e.g., during a rainy season vs. dry), it's challenging to definitively say if an ephemeral gully is visible.
#
# In conclusion:
# - It would be speculative but possible that some of these squares depict the same area at different times.
# - If there were any ephemeral gullies, they might appear as irregularities on the surface in certain images due to water flow after rainfall. However, without additional context or knowledge about when each photo was taken and what conditions led up to it being captured, we cannot conclusively identify them.
#
# Therefore, while one could hypothesize based on visual cues that there may be ephemeral gullies present over time if they were visible in any of these images during periods where water flow occurred through the area, a definitive answer requires more information.
#   1%|█▎                                                                                                    | 4/311 [00:09<11:56,  2.34s/it]
# Based on the provided image alone and assuming that these are indeed photographs taken from an aerial perspective over time, it is not possible to conclusively determine if there have been any changes in ephemeral gully appearances across a span of 10 years due to several factors:
#
# 1. **Resolution Limitations**: The resolution of each photograph appears to be quite low; details that might indicate the presence or absence of an ephemeral gully are obscured.
#
# 2. **Lighting Conditions**: Variations in lighting conditions, such as cloud cover and sun angles, can significantly affect how features appear on a landscape from above. This could obscure any changes over time.
#
# 3. **Scale and Perspective**: Without knowing the exact scale at which these images were taken or their perspective settings (e.g., whether they are straight down views), it is difficult to assess subtle changes in topography that might be indicative of gully formation.
#
# 4. **Image Quality**: The quality of each image, including noise levels and color balance, can affect how features such as ephemeral gullies appear. Poorly exposed or noisy images may not reveal details clearly.
#
# 5. **Temporal Context**: Without knowing the exact dates when these photos were taken relative to one another, it is challenging to determine if any changes are due to seasonal variations rather than long-term environmental processes like erosion leading to gully formation.
#
# In summary, without higher resolution imagery and additional context on lighting conditions, scale, perspective, image quality, and temporal data, we cannot definitively answer whether there have been any ephemeral gully appearances over the 10-year period depicted in these images.
#   2%|█▋                                                                                                    | 5/311 [00:11<11:03,  2.17s/it]
# Based on the provided image alone and assuming that each square represents an observation taken in different seasons or weather conditions (which is not explicitly stated but a common practice when monitoring vegetation), there appears to be no clear evidence of ephemeral gully formation across all six images.
#
# Ephemeral gullies are typically narrow, shallow channels formed by water flow over short periods during heavy rainfall. They can appear and disappear with the seasonal changes in precipitation patterns or due to variations in soil moisture levels.
#
# In this collage:
# 1. The first row shows a consistent green hue without any distinct lines that would suggest erosion.
# 2. In the second image from the top, there is some darker area which could be interpreted as shadow rather than water flow indicating gully formation.
# 3. The third and fourth images in the bottom row show similar shades of green with no visible patterns or lines suggesting recent water flow.
#
# Without additional context such as a timeline showing when each photo was taken, it's challenging to definitively conclude whether ephemeral gullies have appeared over time. However, based on this limited information set, there is nothing that strongly suggests the presence of ephemeral gully formation in any of these images collectively or individually.
#   2%|█▉                                                                                                    | 6/311 [00:12<10:32,  2.07s/it]
# Based on the provided image alone and assuming that each square represents an aerial view taken during different times within a ten-year span, it is challenging to conclusively determine if there are any ephemeral gully appearances across these images due to several factors:
#
# 1. **Resolution Limitations**: The resolution of individual squares appears quite low; details such as the exact shape and depth of potential gullies may not be discernible.
#
# 2. **Lighting Conditions**: Variations in lighting conditions, including shadows cast by clouds or other objects, can obscure features on the ground surface.
#
# 3. **Image Quality**: There is a possibility that image quality degradation over time could affect clarity and detail visibility.
#
# 4. **Temporal Context**: Without knowing specific dates for each square, it's difficult to ascertain if any changes are due to seasonal variations (e.g., snow cover in winter months).
#
# 5. **Scale of Observation**: The scale at which these images were taken is not specified; thus, the size and depth of gullies might be misrepresented.
#
# Without additional information such as exact dates for each image or higher-resolution versions with better lighting conditions, it's impossible to definitively answer whether ephemeral gully appearances are present.
#   2%|██▎                                                                                                   | 7/311 [00:15<10:33,  2.08s/it]
# Based on the provided image alone and assuming that each square represents an aerial view taken during different seasons or weather conditions, it is challenging to definitively identify any ephemeral gully formations across these images collectively due to several factors:
#
# 1. **Consistency in Lighting**: The lighting appears consistent throughout all six squares, suggesting they were likely captured on days with similar atmospheric conditions.
#
# 2. **Lack of Visible Changes Over Time**: Without knowing the specific time intervals between each image or any changes in land use, it is difficult to ascertain if gullies have appeared over a decade without additional context such as topographical data or historical records indicating erosion patterns.
#
# 3. **Uniform Vegetation Coverage**: The green color across all squares suggests that vegetation cover has remained relatively uniform, which could mask the development of new gully formations due to reduced visibility.
#
# 4. **No Visible Erosion Patterns**: There are no clear signs such as streaks or lines indicative of water flow patterns in any single image, making it hard to infer erosion activity over time without more context on rainfall and soil conditions.
#
# In conclusion, based solely on the provided images, there is insufficient evidence to determine if ephemeral gully formations have appeared. Additional information regarding changes in land use, topography, vegetation cover, and weather patterns would be necessary for a comprehensive analysis of such features' development over time.
#   3%|██▌                                                                                                   | 8/311 [00:17<10:16,  2.03s/it]
# Based on the provided image alone and assuming that each square represents an aerial view taken during different seasons or weather conditions, it is challenging to definitively identify any ephemeral gullies due to their transient nature. Ephemeral gullies are typically narrow channels formed by water flow over a short period after heavy rainfall in arid regions.
#
# To determine if there are any appearances of ephemeral gullies:
#
# 1. **Consistency Across Images**: Look for changes or anomalies that could indicate the presence of such features.
# 2. **Color and Texture Variations**: Ephemeral gullies often appear as darker, more textured areas due to wet soil compared to dry ground.
#
# Without additional context on when each image was taken (e.g., after a significant rainfall event), it is difficult to ascertain if any ephemeral gully has appeared over the years. The images do not show clear signs of water flow or distinct channel patterns that would be indicative of an ephemeral gully's presence, especially since such features are typically more pronounced in satellite imagery.
#
# Therefore, based on this single image without temporal context and additional information about when each photo was taken, it is not possible to conclusively determine the appearance of any ephemeral gullies.
#   3%|██▉                                                                                                   | 9/311 [00:18<09:10,  1.82s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear only under certain conditions, such as after rainfall or during specific seasons, it is not possible to conclusively determine if there are any ephemeral gully appearances across all six images collectively.
#
# To accurately assess whether ephemeral gullies have appeared in the area over a 10-year period, one would need additional information about environmental factors like precipitation patterns and land use changes. Without such data or more context on what constitutes "ephemeral" features, any conclusion drawn from these images alone could be speculative.
#
# Therefore, without further contextual details regarding weather conditions, soil type, vegetation cover, and other relevant variables that affect gully formation, it is not possible to provide a definitive answer based solely on the provided collage of six identical-looking images.
#   3%|███▏                                                                                                 | 10/311 [00:20<08:53,  1.77s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear or disappear quickly, such as water flow in a stream bed after rainfall, there is no clear evidence of gully formation across all six images.
#
# The first row shows fields with consistent patterns suggesting agricultural activity. The second row appears more varied but still does not show any distinct signs of erosion like gullies which are typically characterized by V-shaped depressions on the land surface created by water flow over time.
#
# Without additional context such as a timeline, weather conditions during each photo's capture date, or geographical information about the area, it is challenging to definitively conclude whether ephemeral features exist. However, based solely on visual inspection of these images:
#
# - There are no visible V-shaped patterns that would indicate gullies.
# - The fields appear relatively flat and uniform in texture.
#
# Therefore, without more data such as a time-lapse or additional environmental context, it is not possible to confirm the presence of ephemeral features like gullies based on this collage alone.
#   4%|███▌                                                                                                 | 11/311 [00:22<09:28,  1.89s/it]
# Based on the provided image alone and assuming that these are aerial photographs taken from an aircraft or satellite with consistent conditions, it is possible to infer whether there have been any changes in the ephemeral gully appearances over a 10-year period.
#
# Ephemeral gullies typically form during periods of heavy rainfall when water flows rapidly across relatively flat terrain. They can appear and disappear within years due to variations in precipitation patterns or land use practices that affect surface runoff.
#
# To determine if there are any ephemeral gully appearances, one would look for changes between the images:
#
# 1. **Identify Potential Gullies**: Look at each image carefully and identify areas where a sudden change in texture or color could indicate an ephemeral gully.
# 2. **Compare Over Time**: Compare corresponding sections of adjacent images to see if any features have changed shape, size, or position over time.
#
# Without the ability to analyze these specific images further, it is not possible to provide a definitive answer based solely on this description. However, by following these steps and comparing each image with its neighbors in terms of texture changes that could be indicative of gully formation, one might identify any ephemeral gullies present or absent over time.
#
# In conclusion, without additional context such as the location, climate data for those years, land use history, or more detailed analysis tools like GIS software, it is challenging to provide a conclusive answer.
#   4%|███▉                                                                                                 | 12/311 [00:23<09:09,  1.84s/it]
# Based on the provided image alone and assuming that these are aerial photographs taken from roughly the same vantage point with similar conditions, it is challenging to definitively identify any ephemeral gullies across all six images due to their similarity in appearance.
#
# Ephemeral gullies typically refer to small-scale erosion features that appear only during specific weather events or after heavy rainfall. They are often temporary and can be difficult to detect over a short period of time, especially if the area is consistently monitored with similar imagery conditions as seen here.
#
# However, without knowing the exact timing between each photograph's capture date (which would indicate how frequently they were taken), it’s not possible to determine any changes in gully appearance. The images appear very consistent across all six panels, suggesting that there may have been no significant weather events or land use changes during this period that could account for new ephemeral gullies.
#
# In conclusion, without additional context such as the dates of capture and information on environmental conditions over time, it is not possible to conclusively identify any ephemeral gully appearances in these images collectively.
#   4%|████▏                                                                                                | 13/311 [00:26<09:35,  1.93s/it]
# Based on the provided image alone and assuming that each square represents an aerial view taken during different seasons or weather conditions, it is challenging to definitively identify any ephemeral gullies due to their transient nature. Ephemeral gullies are typically narrow channels formed by water flow over a short period of time after heavy rainfall in arid regions.
#
# Here's the reasoning without needing more information:
#
# 1. **Consistency Across Squares**: The images appear consistent across all six squares, suggesting that there is no significant change or disturbance to the landscape between them.
# 2. **Lack of Water Flow Indicators**: There are no clear signs such as water flow lines, erosion patterns, or changes in vegetation density that would indicate recent gully formation.
# 3. **Uniform Vegetation**: The greenery appears uniform across all squares without any noticeable patches where a gully might have formed and then receded.
#
# Without additional context on the specific conditions under which these images were taken (e.g., rainfall amounts, soil type), it is difficult to conclusively determine if ephemeral gullies are present. However, based solely on this image set, there does not appear to be any evidence of recent or ongoing formation of such features.
#
# For a more accurate assessment, one would need data that includes information about the environmental conditions during each photo's capture and possibly even time-lapse images showing changes over years.
#   5%|████▌                                                                                                | 14/311 [00:27<08:50,  1.79s/it]
# Based on the provided image alone and assuming that each row represents one year's worth of data with no temporal gap between images, it appears that in Row 1 (the first two columns), there are ephemeral gullies visible only in Column A ("before" or "after"). In Rows 2 to 6, these features do not appear consistently across all years. This suggests a transient nature of the gully formation.
#
# The reasons for this answer include:
# - The absence of gullies in Columns B and C (Row 1) indicates that they are not present every year.
# - Across Row 2 through Row 6, there is variability with some columns showing ephemeral features while others do not. This inconsistency suggests a non-permanent feature.
#
# Therefore, the presence or absence of these gullies varies over time, which aligns with their description as "ephemeral."
#   5%|████▊                                                                                                | 15/311 [00:29<08:25,  1.71s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear or disappear quickly, it is not possible to conclusively determine if there are any such gullies in this collage due to several factors:
#
# 1. **Resolution Limitation**: The resolution of these satellite images may be insufficient to detect very small-scale features like ephemeral gullies.
# 2. **Image Quality and Processing**: Variations in image quality, including cloud cover obscuring parts of the landscape or processing artifacts that could affect feature detection, are not discernible from this single set of images.
# 3. **Temporal Gap Between Images**: The 10-year span between these images might be too short for some ephemeral features to appear and disappear within such a timeframe.
#
# Without additional information on the specific conditions under which each image was taken or more detailed analysis tools, it is not feasible to definitively identify any ephemeral gullies in this collage.
#   5%|█████▏                                                                                               | 16/311 [00:30<08:40,  1.76s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear only under certain conditions, such as seasonal changes or weather events like rain leading to temporary water flow creating gullies:
#
# 1. **Observation**: The images show a consistent landscape with varying degrees of greenery.
# 2. **Pattern Recognition**: There is no clear pattern indicating the presence of ephemeral gully formation across all years.
# 3. **Consistency in Land Use**: All six images depict what appears to be agricultural fields, which suggests that land use has not changed significantly over time.
#
# Without additional context such as weather data or historical records on rainfall and soil erosion patterns, it is challenging to definitively state the presence of ephemeral gully formation across all years. However, if we consider typical farming practices where plowing can create temporary gullies after heavy rains but these are not persistent features:
#
# - **Reasonable Guess**: It's plausible that any ephemeral gully formations would be transient and not consistently visible in every image due to the variability of weather conditions.
#
# Therefore, based on this analysis alone, it seems unlikely there is a clear pattern indicating the presence of ephemeral gullies across all six images.
#   5%|█████▌                                                                                               | 17/311 [00:32<08:48,  1.80s/it]
# Based on the provided image alone and assuming that each square represents an aerial view taken during different seasons or weather conditions, it is challenging to definitively identify any ephemeral gullies due to their transient nature. Ephemeral gullies are typically narrow channels formed by water flow over a short period of time after heavy rainfall in arid regions.
#
# To determine if there are any appearances of ephemeral gullies:
#
# 1. **Consistency Across Images**: Look for changes or anomalies that could indicate the presence of such features.
# 2. **Seasonal Variations**: Compare images taken during different seasons to see if water flow patterns change, which might suggest temporary channels appearing and disappearing with rainfall.
#
# Without additional context on when each image was captured (e.g., specific dates), it is not possible to conclusively identify ephemeral gullies in this collage alone. A more detailed analysis would require knowing the exact timeframes for each photograph or a series of images showing changes over time, which could indicate the presence and disappearance of such features.
#
# Therefore, based on the provided image without additional information about when they were taken, it is not possible to provide a definitive answer regarding ephemeral gully appearances.
#   6%|█████▊                                                                                               | 18/311 [00:34<09:02,  1.85s/it]
# Based on the provided image alone and assuming that each square represents an aerial view taken during different seasons or weather conditions, it is challenging to definitively identify any ephemeral gully formations across these images collectively due to several factors:
#
# 1. **Consistency in Lighting**: The lighting appears consistent throughout all six squares, suggesting they were likely captured on days with similar cloud cover and sun angles.
#
# 2. **Lack of Visible Changes Over Time**: Without knowing the specific time intervals between each image or any changes in land use, vegetation patterns, or weather conditions that could affect erosion rates, it is difficult to ascertain if gullies have appeared over a decade.
#
# 3. **Resolution Limitations**: The resolution and quality of these images may not capture fine details necessary for identifying small-scale features like ephemeral gully formations.
#
# 4. **Static Nature of the Image Collection**: Since we are presented with static images, any changes that might occur between captures (such as seasonal variations or weather events) would be invisible in this snapshot collection unless there is a time-lapse component not shown here.
#
# Therefore, without additional information such as temporal context, varying environmental conditions, and higher-resolution imagery capturing finer details over the years, it's impossible to conclusively determine if ephemeral gully formations have appeared.
#   6%|██████▏                                                                                              | 19/311 [00:36<08:12,  1.69s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear only under certain conditions, such as after rainfall or during specific seasons, it is not possible to conclusively determine if there are any ephemeral gully appearances in these images collectively.
#
# To accurately assess whether ephemeral gullies have appeared over the 10-year period shown, one would need additional information about environmental factors like precipitation patterns and land use changes. Without such data or a time-lapse sequence showing variations in topography due to weather events, it is not feasible to make an informed conclusion on this matter solely from these images.
#
# Therefore, without further context regarding the conditions under which each image was taken and any known alterations to the landscape during that period, I cannot provide a definitive answer.
#   6%|██████▍                                                                                              | 20/311 [00:38<09:02,  1.86s/it]
# Based on the provided image collage showing satellite imagery from different times (presumably spanning ten years), it is challenging to conclusively determine if there are any ephemeral gullies present in each frame due to several factors:
#
# 1. **Image Resolution**: The resolution of these images may not be high enough to clearly identify small-scale features like ephemeral gullies, especially over a large area.
#
# 2. **Lighting Conditions**: Changes in lighting conditions can affect the visibility of topographical details such as gullies. Shadows and highlights play significant roles in how terrain is perceived from above.
#
# 3. **Temporal Variability**: Ephemeral gullies are typically formed by water flow that occurs infrequently, often after rainfall events. The absence or presence of these features could be due to the timing relative to when they form; for instance, if a particular image was taken during dry conditions, no ephemeral gully might appear.
#
# 4. **Image Quality**: Variations in cloud cover and atmospheric haze can obscure details that are critical for identifying small-scale topographic changes like gullies.
#
# 5. **Scale of Observation**: The scale at which these images were captured may not be fine enough to detect the subtle differences caused by ephemeral processes over time.
#
# Without additional information such as a timeline, context about weather patterns during those years, or higher-resolution imagery that could potentially reveal finer details, it is difficult to definitively state whether there are any ephemeral gullies in these images.
#   7%|██████▊                                                                                              | 21/311 [00:40<09:29,  1.96s/it]
# Based on the provided image collage showing satellite imagery from an identical location taken across ten years, it is challenging to conclusively determine if there are any ephemeral gullies present due to several factors:
#
# 1. **Image Resolution and Quality**: The resolution of these images may not be high enough to clearly identify small-scale features like gullies.
#
# 2. **Lighting Conditions**: Variations in lighting conditions can affect the visibility of topographical details, potentially obscuring any ephemeral gully formations that might appear under different light angles or times of day.
#
# 3. **Temporal Changes**: The images are taken at specific points over a decade; however, without knowing when each image was captured relative to seasonal changes and weather patterns, it's difficult to ascertain if the features shown were indeed temporary gullies rather than permanent ones that might not be visible in all years due to vegetation cover.
#
# 4. **Image Processing**: Any processing or filtering applied during image acquisition could alter the appearance of topographical details, making it harder to identify ephemeral formations like gullies.
#
# 5. **Scale and Perspective**: The scale at which these images are captured may limit their ability to show fine-scale features that would be necessary for identifying short-lived gullies.
#
# Without additional context such as a timeline indicating when each image was taken or more detailed analysis, it is not possible to definitively state whether ephemeral gullies appear in the collage.
#   7%|███████▏                                                                                             | 22/311 [00:42<09:27,  1.96s/it]
# Based on the provided image alone and assuming that these are aerial photographs taken from similar angles to capture changes in land use or vegetation over time, it is possible to infer whether there have been any ephemeral gully appearances.
#
# Ephemeral gullies refer to small-scale water flow channels formed by rainwater runoff which appear only during heavy rainfall events. They can be indicative of soil erosion and are often associated with agricultural practices that disrupt the natural landscape structure.
#
# Upon examining all six images, one would look for changes in land surface features such as new or disappearing lines indicating gullies. These could potentially show up as dark patches where water has flowed through eroded areas on otherwise green fields.
#
# However, without more context about when each photo was taken and what the area's use is (e.g., crop field vs. pasture), it would be challenging to definitively identify ephemeral gully appearances over a decade of data collection. The images provided do not show any clear evidence of such features in all six instances.
#
# Therefore, without additional information on temporal context or specific land management practices that could affect the appearance and disappearance of these channels, we cannot conclusively determine if there are any ephemeral gullies present across this 10-year span based solely on visual inspection.
#   7%|███████▍                                                                                             | 23/311 [00:45<11:10,  2.33s/it]
# Based on the provided image alone and assuming that each square represents one year's worth of data from satellite imagery or similar technology, it appears that there is a pattern in the appearance of what could be interpreted as ephemeral gullies across the six images.
#
# Ephemeral gullies are typically small-scale channels formed by water flow over short periods. They can appear and disappear with changes in weather conditions such as rainfall intensity and frequency.
#
# In examining these squares, one might notice that there is a distinct pattern of green patches which could be indicative of vegetation or crops. Over the span of 10 years, if we consider each square to represent a year's worth of data:
#
# - In some images (notably those in the top row), there are noticeable changes in coloration and texture within these green areas.
#
# This suggests that certain patches may have experienced conditions conducive to gully formation at different times. For instance:
# 1. The first image shows an area with a distinct patch, possibly indicating recent water flow or erosion activity.
# 2. In the second row's images, there are variations in color and texture within what appears to be agricultural fields, which could correlate with periods of rainfall affecting soil stability.
#
# While it is challenging to definitively conclude without more context such as weather data or specific knowledge about land use changes over time, these visual cues suggest that gully formation may have occurred intermittently. The presence of green patches indicates areas where vegetation can grow and potentially be affected by water flow events leading to the appearance of ephemeral gullies.
#
# Therefore, based on this analysis alone:
# Yes, there are indications of ephemeral gully appearances across all six images when viewed together over a period of 10 years. The changes in coloration within what appears to be agricultural fields suggest that certain areas may have experienced conditions leading to the formation and disappearance of such features during different periods.
#
# It is important to note that this interpretation relies on visual analysis alone, which might not capture all aspects or nuances related to gully formations over time. Additional data sources would provide a more comprehensive understanding of these phenomena in the given area.
#   8%|███████▊                                                                                             | 24/311 [00:47<09:42,  2.03s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear or disappear quickly, it is challenging to definitively identify such occurrences in a collage where each photo captures only one moment in time.
#
# However, if we consider changes over multiple years as ephemeral gully appearances, there could be subtle indications of erosion patterns. To accurately determine this, one would need additional information on the specific environmental conditions and land use practices that might have changed during those 10 years. Without such context or a series of images showing progressive change, it is not possible to conclusively identify ephemeral gully appearances in these static snapshots.
#
# Therefore, without more detailed data or a sequence of changes over time, any conclusion about the presence of ephemeral gullies would be speculative and unsupported by the provided image alone.
#   8%|████████                                                                                             | 25/311 [00:49<10:06,  2.12s/it]
# Based on the provided image alone and assuming that each row represents one year's worth of data with no temporal gap between images, it is possible to infer some changes in land use or weather patterns over time.
#
# 1. **Top Row**: The first two images show a consistent dark green field without any visible gullies.
# 2. **Middle Row**: In the second image from the left (top middle), there appears to be an area with lighter coloration, which could indicate either moisture on the soil or some form of disturbance like erosion.
# 3. **Bottom Row**: The last two images show a consistent dark green field without any visible gully.
#
# ### Analysis:
# - There is no clear evidence in this collage that shows ephemeral gullies appearing over time.
# - However, the middle image (top-middle) does suggest some form of disturbance or moisture on the soil which could be related to erosion.
#
# Without additional context such as a timeline and more images from different years, it's challenging to definitively conclude if there are any ephemeral gully appearances.
#
# ### Conclusion:
# Based solely on this collage, no clear evidence suggests that ephemeral gullies appear in these fields over the 10-year period. The only hint of potential disturbance is seen in the middle image (top-middle), but it's not enough to confirm their presence as a recurring feature without more data points.
#
# Therefore, my answer would be: **No** visible evidence from this collage alone suggests that ephemeral gullies appear over time based on these images.
#   8%|████████▍                                                                                            | 26/311 [00:50<09:02,  1.90s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear only under certain conditions, such as after rainfall or during specific seasons:
#
# 1. **Observation**: The images show a consistent green landscape with no visible gullies in any of them.
# 2. **Consistency Across Images**: All six images depict the same area without noticeable changes over time.
#
# **Reasoning for Answer:**
# - Since there are no discernible ephemeral features like gullies present across all images, it suggests that if such features were to appear (e.g., after a rain event), they would not be captured in this set of photographs.
#
# Therefore, based on the provided collage and without additional context or data indicating specific conditions under which these gullies might form, there is no evidence from these images alone to suggest their presence.
#   9%|████████▊                                                                                            | 27/311 [00:51<08:03,  1.70s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear only under certain conditions, such as after rainfall or during specific seasons, it is not possible to conclusively determine if there are any ephemeral gully appearances in all six images collectively.
#
# To accurately answer this question without additional context or data on the environmental factors affecting these areas over time, one would need more information about the local climate patterns, soil composition, vegetation types, and other relevant geographical features. These details could help identify whether certain conditions lead to the formation of gullies in some years but not others.
#
# Without such contextual knowledge, any attempt at identifying ephemeral gully appearances based solely on these images is speculative rather than scientifically grounded.
#   9%|█████████                                                                                            | 28/311 [00:53<07:31,  1.60s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear or disappear quickly, it is not possible to conclusively determine if there are any such features in this collage due to several limitations:
#
# 1. **Resolution**: The images do not have a high enough resolution to clearly identify small-scale ephemeral gullies.
# 2. **Time Gap Between Images**: There's only an 8-year gap between the first and last image, which is insufficient for observing changes that occur on shorter timescales.
# 3. **Consistency Across Images**: All six images appear very similar without any noticeable change in vegetation or water patterns over time.
#
# Therefore, with the given information, it cannot be determined if there are ephemeral gullies present as they would need to show up and disappear within this timeframe of observation.
#   9%|█████████▍                                                                                           | 29/311 [00:55<08:01,  1.71s/it]
# Yes, upon examining these images collectively, it is possible to observe some ephemeral gullies that appear in certain frames but not others. Ephemeral gullies are small-scale water flow channels on a landscape which form and disappear with changes in the hydrological regime.
#
# In this collage:
# 1. The top left image shows no visible gully.
# 2. In the second row, from left to right:
#    - Top-right has faint traces of what could be considered as an ephemeral gully.
#    - Bottom-left appears more uniform without distinct features that suggest a gully's presence.
#
# 3. Finally in the bottom two rows:
#    - The top image shows no visible gully.
#    - In the last row, from left to right:
#      - Top-right has faint traces of what could be considered as an ephemeral gully.
#      - Bottom-left appears more uniform without distinct features that suggest a gully's presence.
#
# The images collectively show variations in land surface texture and coloration which are indicative of changes caused by water flow, suggesting the existence of ephemeral gullies. These appear to form intermittently over time as conditions change (likely due to rainfall patterns), leading to their appearance or disappearance from view between observations.
#  10%|█████████▋                                                                                           | 30/311 [00:57<09:15,  1.98s/it]
# Based on the provided image collage showing satellite imagery from an aerial perspective, it is possible to analyze whether there are any ephemeral gullies present in each frame over a span of 10 years.
#
# Ephemeral gullies refer to small-scale channels that form and disappear seasonally or after rainfall events. They typically appear as narrow, winding depressions on the landscape surface which can be indicative of water flow during specific conditions such as heavy rains.
#
# To determine if there are any ephemeral gully appearances in these images:
#
# 1. **Visual Inspection**: Look for patterns resembling channels that could indicate past water flow.
# 2. **Consistency Across Images**: Check if similar features appear consistently across different years, suggesting a recurring phenomenon rather than random occurrences or artifacts of the imaging process.
#
# Upon examining each image closely:
# - The first row shows what appears to be an open field with no visible gullies in any frame.
# - In the second row, there is some variation; however, none of these features resemble typical ephemeral gully patterns. They seem more like natural soil textures or vegetation patches rather than water flow channels.
#
# Given this analysis:
# There are no clear indications of ephemeral gullies across all six images collected over a period of 10 years in the provided collage. The absence of such distinct, narrow depressions suggests that if any were present, they either do not meet the criteria for being classified as ephemeral or simply did not appear during the time these specific satellite passes captured this area.
#
# Therefore, based on visual evidence alone without additional context like rainfall data and soil type information, it can be concluded that there are no visible ephemeral gullies in any of the images provided.
#  10%|██████████                                                                                           | 31/311 [00:59<08:42,  1.87s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear or disappear quickly, such as seasonal changes in vegetation or temporary water bodies after rainfall:
#
# 1. **Observation**: The images show a consistent pattern of agricultural fields with roads running through them.
# 2. **Consistency Across Years**: There is no visible change from one year's image to the next across any row; all rows appear identical.
#
# Given that there are no changes observed in these six consecutive years, it suggests that if there were ephemeral gullies (temporary water channels), they would not be captured consistently over such a short period. Ephemeral features typically only become visible during specific conditions like heavy rainfall or seasonal melting of snow and ice which is unlikely to occur within the span shown.
#
# Therefore, based on this analysis:
# **Reason**: There are no ephemeral gully appearances in these images because there's no evidence of any changes over a 10-year period. The fields appear unchanged from one year to another.
#  10%|██████████▍                                                                                          | 32/311 [01:01<08:39,  1.86s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear only under certain conditions, such as after rainfall or during specific seasons:
#
# 1. **Observation**: The images show a consistent pattern of green fields with some variation in color intensity.
# 2. **Analysis**:
#    - In all six images, the central part appears consistently brownish-green, which could indicate waterlogged soil typical for agricultural land.
#    - There is no clear evidence of gullies or erosion patterns that would suggest their presence over time without additional context such as changes in weather conditions.
#
# 3. **Reasoning**: Without visible signs of gully formation across all images and the absence of any significant change indicating seasonal effects, it's reasonable to conclude that there are no ephemeral gullies appearing consistently throughout these years based on this collage alone.
# 4. **Conclusion**: Based solely on visual inspection without additional context or data such as weather records, soil analysis, or historical land use changes, we cannot confirm the presence of ephemeral gully features in all images.
#
# Therefore, it appears that there are no consistent appearances of ephemeral gullies across these six years based on this collage.
#  11%|██████████▋                                                                                          | 33/311 [01:03<09:12,  1.99s/it]
# Based on the provided image collage showing what appears to be aerial views of agricultural fields or similar land use over an extended time span, it is not possible to conclusively determine if there are any ephemeral gully appearances across all six images together.
#
# Ephemeral gullies refer to small-scale water flow channels that form and disappear with the onset of rain. They typically appear in dry conditions but can be seen as lines or patches on a landscape when they fill up after rainfall, especially during heavy downpours.
#
# To identify ephemeral gully appearances:
#
# ...
#
# Without additional context or metadata about the collection of each image (such as date, time, weather conditions during capture), it is difficult to definitively state whether ephemeral gullies have appeared over this period based on visual inspection alone. A more detailed analysis involving remote sensing expertise and possibly comparison with ground-truth data would be necessary for a conclusive assessment.
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████   | 302/311 [10:07<00:18,  2.09s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to temporary or transient features such as water flow patterns, it is not possible to conclusively determine if there are any gully appearances in this collage due to several factors:
#
# 1. **Resolution Limitation**: The images appear pixelated, which could obscure finer details necessary for identifying ephemeral gullies.
#
# 2. **Lighting and Weather Conditions**: Variations in lighting conditions over the years can affect how features such as water flow are perceived on a landscape surface.
#
# 3. **Scale of Observation**: Without knowing the scale at which these images were taken or if they represent different scales, it is challenging to assess whether any gully patterns have appeared or changed significantly.
#
# 4. **Temporal Context**: The time span between each image might not be consistent enough for definitive conclusions about changes in ephemeral features like water flow channels.
#
# 5. **Image Quality and Stability**: If the images were taken with varying camera quality, stability, or under different environmental conditions (e.g., droughts), it could affect visibility of gully patterns over time.
#
# In summary, without higher resolution imagery that captures finer details and more context about how these images were captured and processed, any determination regarding ephemeral gullies would be speculative.
#  97%|█████████████████████████████████████████████████████████████████████████████████████████████████▍  | 303/311 [10:09<00:17,  2.24s/it]
# Based on the provided image alone and assuming that each square represents an observation taken approximately one year apart (as suggested by the time span mentioned), it is possible to infer whether there are any ephemeral gully appearances over a period of 10 years.
#
# Ephemeral gullies refer to small, temporary channels or depressions formed on surfaces such as soil. They typically appear during periods of rainfall and then disappear when the water evaporates or drains away.
#
# To determine if there is an appearance of ephemeral gullies in this collage:
#
# 1. **Identify Potential Gully Features**: Look for any lines or patterns that resemble channels, depressions, or irregularities on what appears to be a surface like soil.
# 2. **Compare Across Years**: Compare each square with the others to see if there are consistent features over time.
#
# Upon examining the image:
# - The first row shows no clear signs of gullies in any of its squares.
# - In the second row, one of the images has what could be interpreted as a faint line or depression that might suggest an ephemeral gully. However, it is not consistently present across all years and does not appear to form part of a larger pattern.
#
# Given this analysis:
# There are no clear indications of persistent ephemeral gullies in any of these squares over the 10-year period depicted by the collage. The features that could be interpreted as potential gullies do not show up consistently or suggest an ongoing process like erosion would typically indicate.
#
# Therefore, based on visual evidence alone and assuming a yearly observation interval:
# The answer is no; there are no clear ephemeral gully appearances in this collection of images over 10 years.
#  98%|█████████████████████████████████████████████████████████████████████████████████████████████████▋  | 304/311 [10:11<00:14,  2.13s/it]
# Based on the provided image alone and assuming that "ephemeral" refers to features that appear only under certain conditions, such as seasonal changes or weather events like rain leading to temporary erosion patterns:
#
# 1. **Observation**: The first row shows a consistent green field with no visible gullies.
# 2. **Second Row**: There is one image where the middle section appears darker and more textured than its surroundings, which could suggest moisture accumulation but not necessarily an ephemeral gully.
# 3. **Third Row**: Both images show uniform fields without any noticeable changes or features that would indicate a transient gully.
#
# **Reasoning**: The absence of visible gullies in all six provided images suggests there are no permanent or temporary gullies present at the time these photos were taken. If ephemeral gullies exist, they might not be captured within this specific timeframe and set of conditions depicted by these photographs. To confirm the presence of such features, additional data from different seasons, weather events, or a longer-term study would be necessary.
#
# Therefore, based on the images provided, there are no visible signs of ephemeral gully appearances in any of them collectively over 10 years.
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████  | 305/311 [10:14<00:13,  2.20s/it]
# Based on the provided image collage showing satellite imagery from an agricultural field taken over ten years apart, it is challenging to conclusively determine if there are any ephemeral gullies present in each frame due to several factors:
#
# 1. **Image Resolution and Quality**: The resolution of these images may not be high enough to clearly identify small-scale features like ephemeral gullies.
#
# 2. **Lighting Conditions**: Changes in lighting conditions, such as cloud cover or shadows cast by vegetation, can obscure details that are critical for identifying gullies.
#
# 3. **Temporal Variability**: Ephemeral gullies may not be visible at all times due to seasonal changes; they could appear during periods of heavy rainfall and then disappear when the soil dries out.
#
# 4. **Vegetation Cover**: The presence or absence of vegetation can affect how easily ephemeral features like gullies are discernible in satellite imagery, as plants often fill in depressions left by water flow after it has receded.
#
# 5. **Image Processing Techniques**: Different processing techniques used to create these images might alter the visibility of certain features; for instance, edge detection algorithms may highlight different aspects compared to those that focus on texture or color variations.
#
# Without additional context such as historical data on rainfall patterns, soil type, and land use changes in this area over time, it is not possible to definitively answer whether ephemeral gullies are present. A more detailed analysis involving a combination of satellite imagery with ground-truthing would be necessary for an accurate assessment.
#  98%|██████████████████████████████████████████████████████████████████████████████████████████████████▍ | 306/311 [10:15<00:10,  2.02s/it]
# Based on the provided image alone and assuming that these are aerial photographs taken from similar angles with consistent lighting conditions (which is not explicitly stated but often assumed in such studies), there appears to be a slight variation between some images, particularly noticeable in the top row where one of them shows what looks like an ephemeral gully or depression. This could indicate recent rainfall or other environmental factors that have caused temporary changes in the landscape.
#
# However, without additional context on weather patterns, soil type, and land use practices over time, it's challenging to definitively conclude if these are indeed ephemeral gullies due solely to their appearance across a short span of years. Ephemeral features like this can be influenced by various factors including seasonal changes in vegetation cover, which could obscure or reveal such formations depending on the season.
#
# Therefore, while there is some variation that might suggest an ephemeral feature's presence, it would require more data and context to confirm with certainty whether these are indeed gullies created over time due to natural processes.
#  99%|██████████████████████████████████████████████████████████████████████████████████████████████████▋ | 307/311 [10:17<00:07,  1.94s/it]
# Based on the provided image collage showing aerial views of what appears to be agricultural fields with varying shades of green and brown, it is not possible to conclusively determine if there are any ephemeral gully appearances over a period of 10 years without additional context or data such as soil moisture levels, land use changes, weather patterns, and specific field management practices. Ephemeral gullies typically form in response to heavy rainfall events on slopes with poor vegetation cover, leading to the formation of temporary channels that disappear when there is no rain.
#
# To accurately assess whether ephemeral gully appearances are present or have changed over time, one would need a series of images taken at regular intervals showing changes in land use, soil moisture levels, and other environmental factors. Without such data, any conclusions about the presence of ephemeral gullies based on this image collage alone would be speculative.
#
# Therefore, without additional information regarding temporal variations in these conditions or more detailed analysis techniques like remote sensing software capable of detecting changes over time, it is not possible to provide a definitive answer as to whether there are any ephemeral gully appearances.
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████ | 308/311 [10:19<00:06,  2.03s/it]
# Based on the provided image alone and assuming that each square represents an aerial view taken approximately one year apart (as suggested by the caption), it is possible to infer whether there are any ephemeral gully appearances over time.
#
# Ephemeral gullies refer to small, temporary channels or depressions formed in a landscape. They typically appear during periods of heavy rainfall and then disappear as water evaporates or drains away from the surface.
#
# To determine if such features have appeared:
#
# 1. **Compare Each Pair**: Look at each pair of images (e.g., compare top-left with bottom-left) to see if there are any new depressions that were not present in an earlier image.
# 2. **Identify Changes Over Time**: Note whether these changes persist across multiple years, indicating a recurring pattern.
#
# Without more specific details on the exact locations and conditions under which each photo was taken, it is challenging to definitively conclude about ephemeral gullies' presence or absence over time. However, if any depressions appear in one image but are absent in another within close proximity of other features (like water bodies), they could be indicative of such temporary formations.
#
# In summary:
# - **Reasonable Guess**: If there is a noticeable change between consecutive images that resembles the formation and disappearance pattern typical for ephemeral gullies, it suggests their presence.
#
# This analysis relies on visual inspection alone; actual data or additional context would provide more conclusive evidence.
#  99%|███████████████████████████████████████████████████████████████████████████████████████████████████▎| 309/311 [10:21<00:03,  1.88s/it]
# Based on the provided image alone and assuming that these are aerial photographs taken from an aircraft or satellite with consistent lighting conditions, it is challenging to definitively identify any ephemeral gullies in a collage format where each photo captures only one moment in time.
#
# Ephemeral gullies typically form when water flows over loose soil during rainfall events. They can appear and disappear rapidly depending on the intensity of precipitation and the amount of runoff. In this case, since we are looking at images collected over 10 years without any indication of weather conditions or specific times for each photo, it is not possible to determine if there have been gullies that formed in one image but were no longer present in another.
#
# To accurately identify ephemeral gully appearances, a time-lapse sequence showing changes between the photos would be necessary. Without such information, any attempt at identifying these features based on still images alone could lead to incorrect conclusions or assumptions about their presence over time.
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████▋| 310/311 [10:23<00:02,  2.02s/it]
# Based on the provided image collage showing aerial views of what appears to be agricultural fields or similar land use with roads running through it, one can observe changes over time that suggest some form of activity in these areas.
#
# The first row shows a consistent dark green area which could indicate waterlogged soil or crops. The second and third rows show more varied patterns: the top right image has what looks like an ephemeral gully (a temporary depression formed by running water), while the bottom left appears to have less vegetation, possibly due to erosion.
#
# The fourth row shows a mix of green fields with some brown patches that could be bare soil or areas where crops are not growing. The fifth and sixth rows show more variation in land use; one image has what looks like an ephemeral gully similar to the top right from the second row, while another appears to have less vegetation.
#
# The presence of these patterns suggests human activity such as farming practices that could lead to temporary water flow or erosion events creating gullies. However, without additional context on land use changes over time and weather conditions affecting crop growth, it's challenging to definitively conclude if the ephemeral gully is a recurring feature due to specific activities.
#
# In summary:
# - The images collectively suggest human activity in these areas.
# - There are patterns that could be indicative of temporary water flow or erosion events creating gullies (ephemeral).
# - However, without more context on land use changes and weather conditions affecting crop growth, it's difficult to confirm if the ephemeral gully is a recurring feature due to specific activities.
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████| 311/311 [10:25<00:00,  2.01s/it]
# Based on the provided image collage showing what appears to be satellite or aerial imagery of an agricultural field taken over ten-year intervals, it is not possible to conclusively determine if there are any ephemeral gullies present in all images collectively.
#
# Ephemeral gullies typically refer to small-scale water flow channels that form and disappear with the onset of rain. They can appear as dark lines or patches on a landscape when viewed from above due to their temporary nature, which is not easily captured by static satellite imagery over extended periods without significant changes in land use or weather patterns.
#
# To accurately assess whether ephemeral gullies are present across all images, one would need additional information such as:
#
# 1. Historical data: Information about the field's history and any past agricultural practices that could have led to gully formation.
# 2. Weather records: Data on rainfall amounts over time which can indicate periods of high precipitation conducive to gully development.
# 3. Ground-level observations or satellite imagery with higher temporal resolution.
#
# Without these additional details, it is not feasible to definitively answer whether ephemeral gullies are visible in all images collectively based solely on this collage provided here.

# %%
print(info)
image_file = info[0]
print()
print(image_file)
img = Image.open(image_file)
# Out:
# ['/root/home/data/pos_collage_991.jpg']
#
# /root/home/data/pos_collage_991.jpg
# ---------------------------------------------------------------------------
# UnidentifiedImageError                    Traceback (most recent call last)
# Cell In[22], line 5
#       3 print()
#       4 print(image_file)
# ----> 5 img = Image.open(image_file)
#
# File /opt/conda/lib/python3.10/site-packages/PIL/Image.py:3283, in open(fp, mode, formats)
#    3281     fp.seek(0)
#    3282 except (AttributeError, io.UnsupportedOperation):
# -> 3283     fp = io.BytesIO(fp.read())
#    3284     exclusive_fp = True
#    3286 prefix = fp.read(16)
#
# UnidentifiedImageError: cannot identify image file '/root/home/data/pos_collage_991.jpg'

# %%
pwd
# Out:
# '/mnt/jacket/WACV-2025-Workshop-ViGIR'

# %%
list(saving_response.keys())
#  '629',
#  '631',
#  '636',
#  '639',
#  '643',
#  '644',
#  '646',
#  '666',
#  '668',
#  '669',
#  '670',
#  '681',
#  '685',
#  '686',
#  '691',
#  '695',
#  '701',
#  '706',
#  '711',
#  '719',
#  '721',
#  '722',
#  '723',
#  '724',
#  '727',
#  '851',
#  '852',
#  '854',
#  '855',
#  '857',
#  '859',
#  '865',
#  '866',
#  '867',
#  '878',
#  '881',
#  '882',
#  '887',
#  '895',
#  '898',
#  '903',
#  '907',
#  '910',
#  '911',
#  '914',
#  '915',
#  '916',
#  '918',
#  '923',
#  '927',
#  '928',
#  '930',
#  '932',
#  '942',
#  '944',
#  '945',
#  '950',
#  '955',
#  '956',
#  '965',
#  '966',
#  '967',
#  '972',
#  '973',
#  '975',
#  '991']

# %%
print(saving_response)
# Out:
# {'100': ['/root/home/data/neg_collage_100.jpg', 'Yes, there are ephemeral gully appearances when looking at all of them together. The reason is that each image captures a different moment in time, and these moments can show changes in the landscape over the 10-year period. For example, some images may show more trees or less trees due to seasonal changes, weather patterns, or human activity. By comparing the images side by side, one can observe these differences and identify any ephemeral gully appearances that were present at different times but not consistently across all images.'], '1004': ['/root/home/data/neg_collage_1004.jpg', 'Yes, there are ephemeral gully appearances when looking at all of them together. The reason is that each image captures a different moment in time, and these moments can show changes in the landscape over the 10-year period. These changes could be due to factors such as weather patterns, soil erosion, or human activity. By comparing the images side by side, one can observe how the area has evolved over time, revealing any temporary changes that may have occurred during specific periods.'], '1005': ['/root/home/data/neg_collage_1005.jpg', 'Yes, there are ephemeral gully appearances when looking at all of them together. The reason is that each image captures a different moment in time, and these moments collectively show changes in the landscape over the 10-year period. These changes could be due to factors such as weather patterns, soil erosion, or human activity. By comparing the images side by side, one can observe how the area has evolved over time, revealing any temporary changes that have occurred during this period.'], '1007': ['/root/home/data/neg_collage_1007.jpg', 'Yes, there are ephemeral gully appearances when looking at all of them together. The reason is that each image captures a different moment in time, and these moments collectively show changes in the area over the 10-year period. These changes may include variations in vegetation growth, weather patterns, or other environmental factors that can cause temporary alterations to the landscape. By comparing the images side by side, one can observe these differences and identify any ephemeral gully appearances that have formed and disappeared during this time frame.'], '1010': ['/root/home/data/neg_collage_1010.jpg', 'Yes, there are ephemeral gully appearances when looking at all of them together. The collage shows different shades of green and brown, which indicates that the area has undergone changes in vegetation over time. These changes could be due to seasonal variations or human activities such as deforestation or agricultural practices. By comparing the images side by side, one can observe these differences and identify areas where gullies have formed or disappeared. The presence of a person in one of the images also suggests that people might have been involved in some of these changes.'], '1015': ['/root/home/data/neg_collage_1015.jpg', "Yes, there are ephemeral gully appearances when looking at all of them together. The reason is that each image captures a different moment in time, and when compared side-by-side, one can observe changes in the landscape over the 10-year period. These changes may include shifts in vegetation growth, soil erosion, or other natural processes that affect the area's appearance. By comparing these images, one can identify patterns or trends in the landscape's evolution over time, which might not be apparent when looking at a single image."], '1017': ['/root/home/data/neg_collage_1017.jpg', 'Yes, there are no visible changes in the image across the different photos. The image is a collage of six identical squares arranged in a 2x3 grid. Each square contains a greenish-blue color with some darker areas and lighter areas. The colors and patterns remain consistent throughout all the images, indicating that they were taken at different times but under the same conditions.'], '1018': ['/root/home/data/ne ...

# %%
saving_response_final = copy.deepcopy(saving_response)

"""
for key, item in saving_response.items():
    if 'yes' in item[1].lower():
        saving_response_final[key].append('4')
        saving_response_final[key].pop(0)
        saving_response_final[key].pop(0)
    if 'no' in item[1].lower():
        saving_response_final[key].append('0')
        saving_response_final[key].pop(0)
        saving_response_final[key].pop(0)
"""
# Out:
# "\nfor key, item in saving_response.items():\n    if 'yes' in item[1].lower():\n        saving_response_final[key].append('4')\n        saving_response_final[key].pop(0)\n        saving_response_final[key].pop(0)\n    if 'no' in item[1].lower():\n        saving_response_final[key].append('0')\n        saving_response_final[key].pop(0)\n        saving_response_final[key].pop(0)\n"

# %%
print(saving_response_final)
# Out:
# {'100': ['/root/home/data/neg_collage_100.jpg', 'Yes, there are ephemeral gully appearances when looking at all of them together. The reason is that each image captures a different moment in time, and these moments can show changes in the landscape over the 10-year period. For example, some images may show more trees or less trees due to seasonal changes, weather patterns, or human activity. By comparing the images side by side, one can observe these differences and identify any ephemeral gully appearances that were present at different times but not consistently across all images.'], '1004': ['/root/home/data/neg_collage_1004.jpg', 'Yes, there are ephemeral gully appearances when looking at all of them together. The reason is that each image captures a different moment in time, and these moments can show changes in the landscape over the 10-year period. These changes could be due to factors such as weather patterns, soil erosion, or human activity. By comparing the images side by side, one can observe how the area has evolved over time, revealing any temporary changes that may have occurred during specific periods.'], '1005': ['/root/home/data/neg_collage_1005.jpg', 'Yes, there are ephemeral gully appearances when looking at all of them together. The reason is that each image captures a different moment in time, and these moments collectively show changes in the landscape over the 10-year period. These changes could be due to factors such as weather patterns, soil erosion, or human activity. By comparing the images side by side, one can observe how the area has evolved over time, revealing any temporary changes that have occurred during this period.'], '1007': ['/root/home/data/neg_collage_1007.jpg', 'Yes, there are ephemeral gully appearances when looking at all of them together. The reason is that each image captures a different moment in time, and these moments collectively show changes in the area over the 10-year period. These changes may include variations in vegetation growth, weather patterns, or other environmental factors that can cause temporary alterations to the landscape. By comparing the images side by side, one can observe these differences and identify any ephemeral gully appearances that have formed and disappeared during this time frame.'], '1010': ['/root/home/data/neg_collage_1010.jpg', 'Yes, there are ephemeral gully appearances when looking at all of them together. The collage shows different shades of green and brown, which indicates that the area has undergone changes in vegetation over time. These changes could be due to seasonal variations or human activities such as deforestation or agricultural practices. By comparing the images side by side, one can observe these differences and identify areas where gullies have formed or disappeared. The presence of a person in one of the images also suggests that people might have been involved in some of these changes.'], '1015': ['/root/home/data/neg_collage_1015.jpg', "Yes, there are ephemeral gully appearances when looking at all of them together. The reason is that each image captures a different moment in time, and when compared side-by-side, one can observe changes in the landscape over the 10-year period. These changes may include shifts in vegetation growth, soil erosion, or other natural processes that affect the area's appearance. By comparing these images, one can identify patterns or trends in the landscape's evolution over time, which might not be apparent when looking at a single image."], '1017': ['/root/home/data/neg_collage_1017.jpg', 'Yes, there are no visible changes in the image across the different photos. The image is a collage of six identical squares arranged in a 2x3 grid. Each square contains a greenish-blue color with some darker areas and lighter areas. The colors and patterns remain consistent throughout all the images, indicating that they were taken at different times but under the same conditions.'], '1018': ['/root/home/data/ne ...

# %%
# Save the dictionary as a JSON file
filename = 'reason_first_results_'+args.modelname+'.json'
with open(os.path.join(args.results_dir, filename), 'w') as json_file:
    json.dump(saving_response_final, json_file, indent=4)

print(f"JSON file {filename} has been created.")
# Out:
# JSON file reason_first_results_llava-llama3:8b.json has been created.

# %%
# Read and display the images
#images = [Image.open(path) for path in info]
#images = [[key, item[0]] for key, items in saving_response.items()]
image_number = '1043'
print('Displaying image: ', image_number)
image_file = saving_response[image_number][0]
img = Image.open(image_file)
plt.imshow(img)
plt.tight_layout()
plt.show()
# Out:
# Displaying image:  1043
