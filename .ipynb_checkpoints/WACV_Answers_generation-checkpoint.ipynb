# %%
import ollama 
import os
from tqdm import tqdm
import json
import signal
import argparse
import wandb
import pandas as pd

import sys
from collections import defaultdict

from  utilities import *

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
sys.argv = [
    'notebook',  
    '--modelname', 'llava:7b',
    '--data', 'gully',
    '--data_path','/home1/pupil/goowfd/CVPR_2025/hateful_memes/',
    "--data_samples", 'train.jsonl',
    "--subset", 'train',
    '--results_dir', '/home1/pupil/goowfd/CVPR_2025/hateful_memes/results/baselineExp',
    '--timeout', '20',
    '--model_unloading'
]

# %%
parser = argparse.ArgumentParser(description="A script to run V-LLMs on different image classification datasets")

# %%
parser.add_argument("--modelname", type=str, required=True, help="The name of the V-LLM model")
parser.add_argument("--data", type=str, required=True, help="Dataset name")
parser.add_argument("--data_path", type=str, required=True, help="Path to the image data dir")
parser.add_argument("--data_samples", type=str, required=True, help="Name of the samples to run on")
parser.add_argument("--subset", type=str, required=True, help="train, test or validation set")
parser.add_argument("--results_dir", type=str, required=True, help="Folder name to save results")
parser.add_argument("--timeout", type=int, default=40, help="time out duration to skip one sample")
parser.add_argument("--model_unloading", action="store_true", help="Enables unloading mode. Every 100 sampels it unloades the model from the GPU to avoid carshing.")


args = parser.parse_args()

# %%
# Set up the run 
run = wandb.init(
    entity="ramytrm",
    project=f"wacv-2025-{args.data}",
    name="run_test_" + args.data+"-"+args.modelname+"-"+args.subset
)
# Out:
# wandb: Using wandb-core as the SDK backend. Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: ramytrm. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.18.5
# Run data is saved locally in <code>/root/home/code/wandb/run-20241104_164846-y6er6nru</code>
# Syncing run <strong><a href='https://wandb.ai/ramytrm/wacv-2025-gully/runs/y6er6nru' target="_blank">run_test_gully-llava:7b-train</a></strong> to <a href='https://wandb.ai/ramytrm/wacv-2025-gully' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ramytrm/wacv-2025-gully' target="_blank">https://wandb.ai/ramytrm/wacv-2025-gully</a>
#  View run at <a href='https://wandb.ai/ramytrm/wacv-2025-gully/runs/y6er6nru' target="_blank">https://wandb.ai/ramytrm/wacv-2025-gully/runs/y6er6nru</a>

# %%
directory = '/root/home/data_jpg'
tile_dict = defaultdict(list)

for filename in os.listdir(directory):
    if filename.endswith('.jpg'):
        parts = filename.split('_')
        tile_number = parts[4].split('.')[0]
        tile_dict[tile_number].append(os.path.join(directory,filename))

tile_dict = dict(tile_dict)

# %%
for tile_number, file_list in tile_dict.items():
    tile_dict[tile_number] = sorted(file_list, key=lambda x: int(x.split('_')[3]))

# %%
unwanted_patterns = ['rgb_0', 'rgb_2', 'rgb_4']

# %%
data = {key: [path for path in paths if not any(sub in path for sub in unwanted_patterns)] 
        for key, paths in tile_dict.items()}

# %%
data
# Out:
# {'405': ['/root/home/data_jpg/pos_rgb_0_tile_405.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_405.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_405.jpg'],
#  '730': ['/root/home/data_jpg/pos_rgb_0_tile_730.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_730.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_730.jpg'],
#  '223': ['/root/home/data_jpg/pos_rgb_0_tile_223.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_223.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_223.jpg'],
#  '573': ['/root/home/data_jpg/pos_rgb_0_tile_573.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_573.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_573.jpg'],
#  '144': ['/root/home/data_jpg/pos_rgb_0_tile_144.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_144.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_144.jpg'],
#  '563': ['/root/home/data_jpg/pos_rgb_0_tile_563.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_563.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_563.jpg'],
#  '855': ['/root/home/data_jpg/pos_rgb_0_tile_855.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_855.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_855.jpg'],
#  '927': ['/root/home/data_jpg/pos_rgb_0_tile_927.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_927.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_927.jpg'],
#  '594': ['/root/home/data_jpg/pos_rgb_0_tile_594.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_594.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_594.jpg'],
#  '368': ['/root/home/data_jpg/pos_rgb_0_tile_368.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_368.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_368.jpg'],
#  '870': ['/root/home/data_jpg/pos_rgb_0_tile_870.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_870.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_870.jpg'],
#  '232': ['/root/home/data_jpg/pos_rgb_0_tile_232.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_232.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_232.jpg'],
#  '3': ['/root/home/data_jpg/pos_rgb_0_tile_3.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_3.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_3.jpg'],
#  '165': ['/root/home/data_jpg/pos_rgb_0_tile_165.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_165.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_165.jpg'],
#  '235': ['/root/home/data_jpg/pos_rgb_0_tile_235.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_235.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_235.jpg'],
#  '861': ['/root/home/data_jpg/pos_rgb_0_tile_861.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_861.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_861.jpg'],
#  '560': ['/root/home/data_jpg/pos_rgb_0_tile_560.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_560.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_560.jpg'],
#  '883': ['/root/home/data_jpg/pos_rgb_0_tile_883.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_883.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_883.jpg'],
#  '915': ['/root/home/data_jpg/pos_rgb_0_tile_915.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_915.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_915.jpg'],
#  '140': ['/root/home/data_jpg/pos_rgb_0_tile_140.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_140.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_140.jpg'],
#  '215': ['/root/home/data_jpg/pos_rgb_0_tile_215.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_215.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_215.jpg'],
#  '895': ['/root/home/data_jpg/pos_rgb_0_tile_895.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_895.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_895.jpg'],
#  '607': ['/root/home/data_jpg/pos_rgb_0_tile_607.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_607.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_607.jpg'],
#  '416': ['/root/home/data_jpg/pos_rgb_0_tile_416.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_416.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_416.jpg'],
#  '217': ['/root/home/data_jpg/pos_rgb_0_tile_217.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_217.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_217.jpg'],
#  '697': ['/root/home/data_jpg/pos_rgb_0_tile_697.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_697.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_697.jpg'],
#  '436': ['/root/home/data_jpg/pos_rgb_0_tile_436.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_436.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_436.jpg'],
#  '647': ['/root/home/data_jpg/pos_rgb_0_tile_647.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_647.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_647.jpg'],
#  '967': ['/root/home/data_jpg/pos_rgb_0_tile_967.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_967.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_967.jpg'],
#  '26': ['/root/home/data_jpg/pos_rgb_0_tile_26.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_26.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_26.jpg'],
#  '858': ['/root/home/data_jpg/pos_rgb_0_tile_858.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_858.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_858.jpg'],
#  '953': ['/root/home/data_jpg/pos_rgb_0_tile_953.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_953.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_953.jpg'],
#  '31': ['/root/home/data_jpg/pos_rgb_0_tile_31.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_31.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_31.jpg'],
#  '949': ['/root/home/data_jpg/pos_rgb_0_tile_949.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_949.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_949.jpg'],
#  '942': ['/root/home/data_jpg/pos_rgb_0_tile_942.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_942.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_942.jpg'],
#  '21': ['/root/home/data_jpg/pos_rgb_0_tile_21.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_21.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_21.jpg'],
#  '727': ['/root/home/data_jpg/pos_rgb_0_tile_727.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_727.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_727.jpg'],
#  '952': ['/root/home/data_jpg/pos_rgb_0_tile_952.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_952.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_952.jpg'],
#  '244': ['/root/home/data_jpg/pos_rgb_0_tile_244.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_244.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_244.jpg'],
#  '9': ['/root/home/data_jpg/pos_rgb_0_tile_9.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_9.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_9.jpg'],
#  '377': ['/root/home/data_jpg/pos_rgb_0_tile_377.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_377.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_377.jpg'],
#  '233': ['/root/home/data_jpg/pos_rgb_0_tile_233.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_233.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_233.jpg'],
#  '567': ['/root/home/data_jpg/pos_rgb_0_tile_567.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_567.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_567.jpg'],
#  '711': ['/root/home/data_jpg/pos_rgb_0_tile_711.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_711.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_711.jpg'],
#  '996': ['/root/home/data_jpg/pos_rgb_0_tile_996.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_996.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_996.jpg'],
#  '55': ['/root/home/data_jpg/pos_rgb_0_tile_55.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_55.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_55.jpg'],
#  '214': ['/root/home/data_jpg/pos_rgb_0_tile_214.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_214.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_214.jpg'],
#  '428': ['/root/home/data_jpg/pos_rgb_0_tile_428.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_428.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_428.jpg'],
#  '392': ['/root/home/data_jpg/pos_rgb_0_tile_392.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_392.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_392.jpg'],
#  '576': ['/root/home/data_jpg/pos_rgb_0_tile_576.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_576.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_576.jpg'],
#  '566': ['/root/home/data_jpg/pos_rgb_0_tile_566.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_566.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_566.jpg'],
#  '364': ['/root/home/data_jpg/pos_rgb_0_tile_364.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_364.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_364.jpg'],
#  '418': ['/root/home/data_jpg/pos_rgb_0_tile_418.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_418.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_418.jpg'],
#  '23': ['/root/home/data_jpg/pos_rgb_0_tile_23.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_23.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_23.jpg'],
#  '8': ['/root/home/data_jpg/pos_rgb_0_tile_8.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_8.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_8.jpg'],
#  '622': ['/root/home/data_jpg/pos_rgb_0_tile_622.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_622.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_622.jpg'],
#  '558': ['/root/home/data_jpg/pos_rgb_0_tile_558.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_558.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_558.jpg'],
#  '552': ['/root/home/data_jpg/pos_rgb_0_tile_552.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_552.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_552.jpg'],
#  '913': ['/root/home/data_jpg/pos_rgb_0_tile_913.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_913.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_913.jpg'],
#  '173': ['/root/home/data_jpg/pos_rgb_0_tile_173.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_173.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_173.jpg'],
#  '593': ['/root/home/data_jpg/pos_rgb_0_tile_593.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_593.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_593.jpg'],
#  '38': ['/root/home/data_jpg/pos_rgb_0_tile_38.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_38.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_38.jpg'],
#  '391': ['/root/home/data_jpg/pos_rgb_0_tile_391.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_391.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_391.jpg'],
#  '890': ['/root/home/data_jpg/pos_rgb_0_tile_890.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_890.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_890.jpg'],
#  '5': ['/root/home/data_jpg/pos_rgb_0_tile_5.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_5.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_5.jpg'],
#  '577': ['/root/home/data_jpg/pos_rgb_0_tile_577.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_577.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_577.jpg'],
#  '556': ['/root/home/data_jpg/pos_rgb_0_tile_556.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_556.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_556.jpg'],
#  '597': ['/root/home/data_jpg/pos_rgb_0_tile_597.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_597.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_597.jpg'],
#  '884': ['/root/home/data_jpg/pos_rgb_0_tile_884.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_884.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_884.jpg'],
#  '4': ['/root/home/data_jpg/pos_rgb_0_tile_4.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_4.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_4.jpg'],
#  '721': ['/root/home/data_jpg/pos_rgb_0_tile_721.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_721.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_721.jpg'],
#  '441': ['/root/home/data_jpg/pos_rgb_0_tile_441.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_441.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_441.jpg'],
#  '702': ['/root/home/data_jpg/pos_rgb_0_tile_702.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_702.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_702.jpg'],
#  '137': ['/root/home/data_jpg/pos_rgb_0_tile_137.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_137.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_137.jpg'],
#  '644': ['/root/home/data_jpg/pos_rgb_0_tile_644.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_644.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_644.jpg'],
#  '694': ['/root/home/data_jpg/pos_rgb_0_tile_694.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile
jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_945.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_945.jpg'],
#  '958': ['/root/home/data_jpg/pos_rgb_0_tile_958.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_958.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_958.jpg'],
#  '911': ['/root/home/data_jpg/pos_rgb_0_tile_911.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_911.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_911.jpg'],
#  '853': ['/root/home/data_jpg/pos_rgb_0_tile_853.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_853.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_853.jpg'],
#  '376': ['/root/home/data_jpg/pos_rgb_0_tile_376.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_376.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_376.jpg'],
#  '625': ['/root/home/data_jpg/pos_rgb_0_tile_625.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_625.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_625.jpg'],
#  '852': ['/root/home/data_jpg/pos_rgb_0_tile_852.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_852.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_852.jpg'],
#  '605': ['/root/home/data_jpg/pos_rgb_0_tile_605.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_605.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_605.jpg'],
#  '409': ['/root/home/data_jpg/pos_rgb_0_tile_409.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_409.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_409.jpg'],
#  '203': ['/root/home/data_jpg/pos_rgb_0_tile_203.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_203.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_203.jpg'],
#  '851': ['/root/home/data_jpg/pos_rgb_0_tile_851.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_851.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_851.jpg'],
#  '882': ['/root/home/data_jpg/pos_rgb_0_tile_882.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_882.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_882.jpg'],
#  '145': ['/root/home/data_jpg/pos_rgb_0_tile_145.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_145.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_145.jpg'],
#  '602': ['/root/home/data_jpg/pos_rgb_0_tile_602.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_602.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_602.jpg'],
#  '393': ['/root/home/data_jpg/pos_rgb_0_tile_393.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_393.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_393.jpg'],
#  '425': ['/root/home/data_jpg/pos_rgb_0_tile_425.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_425.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_425.jpg'],
#  '240': ['/root/home/data_jpg/pos_rgb_0_tile_240.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_240.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_240.jpg'],
#  '712': ['/root/home/data_jpg/pos_rgb_0_tile_712.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_712.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_712.jpg'],
#  '6': ['/root/home/data_jpg/pos_rgb_0_tile_6.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_6.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_6.jpg'],
#  '430': ['/root/home/data_jpg/pos_rgb_0_tile_430.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_430.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_430.jpg'],
#  '619': ['/root/home/data_jpg/pos_rgb_0_tile_619.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_619.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_619.jpg'],
#  '24': ['/root/home/data_jpg/pos_rgb_0_tile_24.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_24.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_24.jpg'],
#  '350': ['/root/home/data_jpg/pos_rgb_0_tile_350.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_350.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_350.jpg'],
#  '955': ['/root/home/data_jpg/pos_rgb_0_tile_955.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_955.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_955.jpg'],
#  '183': ['/root/home/data_jpg/pos_rgb_0_tile_183.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_183.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_183.jpg'],
#  '396': ['/root/home/data_jpg/pos_rgb_0_tile_396.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_396.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_396.jpg'],
#  '175': ['/root/home/data_jpg/pos_rgb_0_tile_175.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_175.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_175.jpg'],
#  '641': ['/root/home/data_jpg/pos_rgb_0_tile_641.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_641.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_641.jpg'],
#  '164': ['/root/home/data_jpg/pos_rgb_0_tile_164.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_164.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_164.jpg'],
#  '663': ['/root/home/data_jpg/pos_rgb_0_tile_663.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_663.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_663.jpg'],
#  '885': ['/root/home/data_jpg/pos_rgb_0_tile_885.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_885.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_885.jpg'],
#  '575': ['/root/home/data_jpg/pos_rgb_0_tile_575.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_575.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_575.jpg'],
#  '52': ['/root/home/data_jpg/pos_rgb_0_tile_52.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_52.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_52.jpg'],
#  '355': ['/root/home/data_jpg/pos_rgb_0_tile_355.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_355.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_355.jpg'],
#  '234': ['/root/home/data_jpg/pos_rgb_0_tile_234.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_234.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_234.jpg'],
#  '975': ['/root/home/data_jpg/pos_rgb_0_tile_975.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_975.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_975.jpg'],
#  '947': ['/root/home/data_jpg/pos_rgb_0_tile_947.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_947.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_947.jpg'],
#  '372': ['/root/home/data_jpg/pos_rgb_0_tile_372.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_372.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_372.jpg'],
#  '365': ['/root/home/data_jpg/pos_rgb_0_tile_365.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_365.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_365.jpg'],
#  '536': ['/root/home/data_jpg/pos_rgb_0_tile_536.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_536.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_536.jpg'],
#  '33': ['/root/home/data_jpg/pos_rgb_0_tile_33.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_33.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_33.jpg'],
#  '610': ['/root/home/data_jpg/pos_rgb_0_tile_610.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_610.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_610.jpg'],
#  '371': ['/root/home/data_jpg/pos_rgb_0_tile_371.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_371.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_371.jpg'],
#  '150': ['/root/home/data_jpg/pos_rgb_0_tile_150.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_150.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_150.jpg'],
#  '400': ['/root/home/data_jpg/pos_rgb_0_tile_400.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_400.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_400.jpg'],
#  '916': ['/root/home/data_jpg/pos_rgb_0_tile_916.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_916.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_916.jpg'],
#  '381': ['/root/home/data_jpg/pos_rgb_0_tile_381.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_381.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_381.jpg'],
#  '669': ['/root/home/data_jpg/pos_rgb_0_tile_669.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_669.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_669.jpg'],
#  '172': ['/root/home/data_jpg/pos_rgb_0_tile_172.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_172.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_172.jpg'],
#  '176': ['/root/home/data_jpg/pos_rgb_0_tile_176.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_176.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_176.jpg'],
#  '397': ['/root/home/data_jpg/pos_rgb_0_tile_397.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_397.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_397.jpg'],
#  '208': ['/root/home/data_jpg/pos_rgb_0_tile_208.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_208.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_208.jpg'],
#  '679': ['/root/home/data_jpg/pos_rgb_0_tile_679.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_679.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_679.jpg'],
#  '903': ['/root/home/data_jpg/pos_rgb_0_tile_903.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_903.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_903.jpg'],
#  '1': ['/root/home/data_jpg/pos_rgb_0_tile_1.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_1.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_1.jpg'],
#  '649': ['/root/home/data_jpg/pos_rgb_0_tile_649.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_649.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_649.jpg'],
#  '209': ['/root/home/data_jpg/pos_rgb_0_tile_209.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_209.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_209.jpg'],
#  '587': ['/root/home/data_jpg/pos_rgb_0_tile_587.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_587.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_587.jpg'],
#  '860': ['/root/home/data_jpg/pos_rgb_0_tile_860.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_860.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_860.jpg'],
#  '67': ['/root/home/data_jpg/pos_rgb_0_tile_67.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_67.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_67.jpg'],
#  '539': ['/root/home/data_jpg/pos_rgb_0_tile_539.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_539.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_539.jpg'],
#  '629': ['/root/home/data_jpg/pos_rgb_0_tile_629.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_629.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_629.jpg'],
#  '166': ['/root/home/data_jpg/pos_rgb_0_tile_166.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_166.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_166.jpg'],
#  '367': ['/root/home/data_jpg/pos_rgb_0_tile_367.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_367.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_367.jpg'],
#  '568': ['/root/home/data_jpg/pos_rgb_0_tile_568.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_568.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_568.jpg'],
#  '584': ['/root/home/data_jpg/pos_rgb_0_tile_584.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_584.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_584.jpg'],
#  '555': ['/root/home/data_jpg/pos_rgb_0_tile_555.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_555.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_555.jpg'],
#  '401': ['/root/home/data_jpg/pos_rgb_0_tile_401.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_401.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_401.jpg'],
#  '635': ['/root/home/data_jpg/pos_rgb_0_tile_635.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_635.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_635.jpg'],
#  '239': ['/root/home/data_jpg/pos_rgb_0_tile_239.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile
jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_202.jpg'],
#  '413': ['/root/home/data_jpg/pos_rgb_0_tile_413.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_413.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_413.jpg'],
#  '603': ['/root/home/data_jpg/pos_rgb_0_tile_603.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_603.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_603.jpg'],
#  '421': ['/root/home/data_jpg/pos_rgb_0_tile_421.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_421.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_421.jpg'],
#  '992': ['/root/home/data_jpg/pos_rgb_0_tile_992.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_992.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_992.jpg'],
#  '995': ['/root/home/data_jpg/pos_rgb_0_tile_995.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_995.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_995.jpg'],
#  '181': ['/root/home/data_jpg/pos_rgb_0_tile_181.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_181.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_181.jpg'],
#  '599': ['/root/home/data_jpg/pos_rgb_0_tile_599.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_599.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_599.jpg'],
#  '946': ['/root/home/data_jpg/pos_rgb_0_tile_946.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_946.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_946.jpg'],
#  '162': ['/root/home/data_jpg/pos_rgb_0_tile_162.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_162.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_162.jpg'],
#  '923': ['/root/home/data_jpg/pos_rgb_0_tile_923.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_923.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_923.jpg'],
#  '725': ['/root/home/data_jpg/pos_rgb_0_tile_725.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_725.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_725.jpg'],
#  '190': ['/root/home/data_jpg/pos_rgb_0_tile_190.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_190.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_190.jpg'],
#  '691': ['/root/home/data_jpg/pos_rgb_0_tile_691.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_691.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_691.jpg'],
#  '623': ['/root/home/data_jpg/pos_rgb_0_tile_623.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_623.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_623.jpg'],
#  '386': ['/root/home/data_jpg/pos_rgb_0_tile_386.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_386.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_386.jpg'],
#  '618': ['/root/home/data_jpg/pos_rgb_0_tile_618.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_618.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_618.jpg'],
#  '944': ['/root/home/data_jpg/pos_rgb_0_tile_944.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_944.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_944.jpg'],
#  '545': ['/root/home/data_jpg/pos_rgb_0_tile_545.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_545.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_545.jpg'],
#  '859': ['/root/home/data_jpg/pos_rgb_0_tile_859.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_859.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_859.jpg'],
#  '534': ['/root/home/data_jpg/pos_rgb_0_tile_534.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_534.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_534.jpg'],
#  '919': ['/root/home/data_jpg/pos_rgb_0_tile_919.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_919.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_919.jpg'],
#  '639': ['/root/home/data_jpg/pos_rgb_0_tile_639.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_639.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_639.jpg'],
#  '678': ['/root/home/data_jpg/pos_rgb_0_tile_678.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_678.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_678.jpg'],
#  '433': ['/root/home/data_jpg/pos_rgb_0_tile_433.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_433.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_433.jpg'],
#  '561': ['/root/home/data_jpg/pos_rgb_0_tile_561.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_561.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_561.jpg'],
#  '541': ['/root/home/data_jpg/pos_rgb_0_tile_541.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_541.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_541.jpg'],
#  '917': ['/root/home/data_jpg/pos_rgb_0_tile_917.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_917.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_917.jpg'],
#  '642': ['/root/home/data_jpg/pos_rgb_0_tile_642.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_642.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_642.jpg'],
#  '686': ['/root/home/data_jpg/pos_rgb_0_tile_686.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_686.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_686.jpg'],
#  '420': ['/root/home/data_jpg/pos_rgb_0_tile_420.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_420.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_420.jpg'],
#  '226': ['/root/home/data_jpg/pos_rgb_0_tile_226.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_226.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_226.jpg'],
#  '646': ['/root/home/data_jpg/pos_rgb_0_tile_646.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_646.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_646.jpg'],
#  '668': ['/root/home/data_jpg/pos_rgb_0_tile_668.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_668.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_668.jpg'],
#  '196': ['/root/home/data_jpg/pos_rgb_0_tile_196.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_196.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_196.jpg'],
#  '565': ['/root/home/data_jpg/pos_rgb_0_tile_565.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_565.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_565.jpg'],
#  '926': ['/root/home/data_jpg/pos_rgb_0_tile_926.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_926.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_926.jpg'],
#  '406': ['/root/home/data_jpg/pos_rgb_0_tile_406.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_406.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_406.jpg'],
#  '962': ['/root/home/data_jpg/pos_rgb_0_tile_962.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_962.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_962.jpg'],
#  '703': ['/root/home/data_jpg/pos_rgb_0_tile_703.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_703.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_703.jpg'],
#  '16': ['/root/home/data_jpg/pos_rgb_0_tile_16.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_16.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_16.jpg'],
#  '362': ['/root/home/data_jpg/pos_rgb_0_tile_362.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_362.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_362.jpg'],
#  '20': ['/root/home/data_jpg/pos_rgb_0_tile_20.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_20.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_20.jpg'],
#  '677': ['/root/home/data_jpg/pos_rgb_0_tile_677.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_677.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_677.jpg'],
#  '687': ['/root/home/data_jpg/pos_rgb_0_tile_687.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_687.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_687.jpg'],
#  '17': ['/root/home/data_jpg/pos_rgb_0_tile_17.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_17.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_17.jpg'],
#  '407': ['/root/home/data_jpg/pos_rgb_0_tile_407.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_407.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_407.jpg'],
#  '359': ['/root/home/data_jpg/pos_rgb_0_tile_359.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_359.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_359.jpg'],
#  '204': ['/root/home/data_jpg/pos_rgb_0_tile_204.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_204.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_204.jpg'],
#  '893': ['/root/home/data_jpg/pos_rgb_0_tile_893.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_893.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_893.jpg'],
#  '395': ['/root/home/data_jpg/pos_rgb_0_tile_395.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_395.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_395.jpg'],
#  '28': ['/root/home/data_jpg/pos_rgb_0_tile_28.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_28.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_28.jpg'],
#  '922': ['/root/home/data_jpg/pos_rgb_0_tile_922.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_922.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_922.jpg'],
#  '997': ['/root/home/data_jpg/pos_rgb_0_tile_997.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_997.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_997.jpg'],
#  '360': ['/root/home/data_jpg/pos_rgb_0_tile_360.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_360.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_360.jpg'],
#  '14': ['/root/home/data_jpg/pos_rgb_0_tile_14.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_14.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_14.jpg'],
#  '624': ['/root/home/data_jpg/pos_rgb_0_tile_624.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_624.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_624.jpg'],
#  '193': ['/root/home/data_jpg/pos_rgb_0_tile_193.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_193.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_193.jpg'],
#  '194': ['/root/home/data_jpg/pos_rgb_0_tile_194.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_194.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_194.jpg'],
#  '956': ['/root/home/data_jpg/pos_rgb_0_tile_956.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_956.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_956.jpg'],
#  '676': ['/root/home/data_jpg/pos_rgb_0_tile_676.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_676.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_676.jpg'],
#  '179': ['/root/home/data_jpg/pos_rgb_0_tile_179.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_179.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_179.jpg'],
#  '707': ['/root/home/data_jpg/pos_rgb_0_tile_707.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_707.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_707.jpg'],
#  '434': ['/root/home/data_jpg/pos_rgb_0_tile_434.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_434.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_434.jpg'],
#  '988': ['/root/home/data_jpg/pos_rgb_0_tile_988.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_988.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_988.jpg'],
#  '978': ['/root/home/data_jpg/pos_rgb_0_tile_978.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_978.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_978.jpg'],
#  '218': ['/root/home/data_jpg/pos_rgb_0_tile_218.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_218.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_218.jpg'],
#  '189': ['/root/home/data_jpg/pos_rgb_0_tile_189.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_189.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_189.jpg'],
#  '219': ['/root/home/data_jpg/pos_rgb_0_tile_219.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_219.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_219.jpg'],
#  '596': ['/root/home/data_jpg/pos_rgb_0_tile_596.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_596.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_596.jpg'],
#  '237': ['/root/home/data_jpg/pos_rgb_0_tile_237.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_237.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_237.jpg'],
#  '866': ['/root/home/data_jpg/pos_rgb_0_tile_866.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_866.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_866.jpg'],
#  '671': ['/root/home/data_jpg/pos_rgb_0_tile_671.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_671.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_671.jpg'],
#  '557': ['/root/home/data_jpg/pos_rgb_0_tile_557.jpg',
#   '/root/home/data_jpg/pos_rgb_3_tile_557.jpg',
#   '/root/home/data_jpg/pos_rgb_5_tile_557.jpg']}

# %%
questions = [
    "Across the images, do you see a low point in the terrain where a temporary gully or depression begins to form without a permanent water feature? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Do narrow, winding paths or channels appear and become more defined across the sequence? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Over time, do any linear depressions or ruts become more pronounced along natural drainage lines or slopes? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Does a narrow, shallow channel become visibly deeper or more indented into the soil over the image sequence? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Are there areas where soil appears disturbed or vegetation is removed, showing progression over the images? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Across the sequence, does a specific path lack vegetation, suggesting an evolving or emerging channel? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Does the texture of the soil appear to change, becoming coarser or showing small pebbles in areas that develop into channels? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Can you see any clear starting and ending points for these channels becoming more evident over time? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Do small rills or grooves indicating water flow appear or deepen across the images? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Is there a gradual exposure of lighter-colored soil as the gully forms? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Are there sediment accumulations forming at the lower ends of channels as time progresses? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Across the images, do signs of water activity, like soil clumps or crusting, appear or intensify in specific areas? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Do shallow side walls along the channel areas become more defined as the sequence progresses? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Do deposits of silt or small debris appear and accumulate along any emerging channel paths? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Can you observe branching patterns that resemble temporary streams forming or intensifying over time? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Do areas with compacted soil or minor slope collapse become more noticeable along the developing channel edges? Please answer with YES or NO Only. DO NOT mention the reason.",
    "Are there indications of nearby human activity, such as tillage or machinery tracks, influencing the formation or expansion of these channels? Please answer with YES or NO Only. DO NOT mention the reason."
]

# %%
model_name = args.modelname
ollama.pull(model_name)

timeout_duration = args.timeout

options= {  # new
            "seed": 123,
            "temperature": 0,
            "num_ctx": 2048, # must be set, otherwise slightly random output
        }

model_labels = {}
count = 0

# %%
count=0
saving_response=dict(tile_dict)

for key,info in tqdm(data.items()):

    count+=1
    for question in questions:
        response = ollama.generate(model=model_name, prompt=question, images=info, options=options)
        saving_response[key].append(response['response'])
        print(response['response'])
# Out:
#   0%|                                               | 0/450 [00:00<?, ?it/s]
#  Yes
#  No
#  Yes
#  No
#  Yes
#  Yes
#  Yes
#  No
#  No
#  No
#  No
#  No
#  Yes
#  No
#  No.
#  Yes
#   0%|                                     | 1/450 [00:54<6:45:23, 54.17s/it]
#  No
#  Yes
#  Yes
#  Yes
#  No
#  Yes
#  Yes
#  Yes
#  No
#  No
#  Yes
#  Yes
#  Yes
#  Yes
#  Yes
#  Yes
#  Yes
#   0%|▏                                    | 2/450 [01:48<6:47:15, 54.54s/it]
#  Yes
#  Yes
#  Yes
#  Yes
#  No
#  Yes
#  Yes
#  Yes
#  Yes
#  No
#  Yes
#  Yes
#  Yes
#  Yes
#  Yes
#  Yes
#  Yes
#   1%|▏                                    | 3/450 [02:45<6:51:45, 55.27s/it]
#  No
#  No
#  No
#  Yes
#  No
#  No
#  Yes
#  No
#  No
#  No
#  No
#  No
#  No
#  No
#  No
#  No
#  Yes
#   1%|▎                                    | 4/450 [03:41<6:53:16, 55.60s/it]
#  No
#  Yes
#  No
#  Yes
#  No
#  Yes
#  Yes
#  No
#  No
#  No
#  Yes
#  No
#  No
#  No
#  Yes
#  No.
#  Yes
#   1%|▍                                    | 5/450 [04:37<6:53:36, 55.77s/it]
#  Yes
#  Yes
#  Yes
#  Yes
#  No
#  Yes
#   1%|▍                                    | 5/450 [04:55<7:18:47, 59.16s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 8
#       6 count+=1
#       7 for question in questions:
# ----> 8     response = ollama.generate(model=model_name, prompt=question, images=info, options=options)
#       9     saving_response[key].append(response['response'])
#      10     print(response['response'])
#
# File /opt/conda/lib/python3.10/site-packages/ollama/_client.py:163, in Client.generate(self, model, prompt, suffix, system, template, context, stream, raw, format, images, options, keep_alive)
#     160 if not model:
#     161   raise RequestError('must provide a model')
# --> 163 return self._request_stream(
#     164   'POST',
#     165   '/api/generate',
#     166   json={
#     167     'model': model,
#     168     'prompt': prompt,
#     169     'suffix': suffix,
#     170     'system': system,
#     171     'template': template,
#     172     'context': context or [],
#     173     'stream': stream,
#     174     'raw': raw,
#     175     'images': [_encode_image(image) for image in images or []],
#     176     'format': format,
#     177     'options': options or {},
#     178     'keep_alive': keep_alive,
#     179   },
#     180   stream=stream,
#     181 )
#
# File /opt/conda/lib/python3.10/site-packages/ollama/_client.py:99, in Client._request_stream(self, stream, *args, **kwargs)
#      93 def _request_stream(
#      94   self,
#      95   *args,
#      96   stream: bool = False,
#      97   **kwargs,
#      98 ) -> Union[Mapping[str, Any], Iterator[Mapping[str, Any]]]:
# ---> 99   return self._stream(*args, **kwargs) if stream else self._request(*args, **kwargs).json()
#
# File /opt/conda/lib/python3.10/site-packages/ollama/_client.py:70, in Client._request(self, method, url, **kwargs)
#      69 def _request(self, method: str, url: str, **kwargs) -> httpx.Response:
# ---> 70   response = self._client.request(method, url, **kwargs)
#      72   try:
#      73     response.raise_for_status()
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_client.py:837, in Client.request(self, method, url, content, data, files, json, params, headers, cookies, auth, follow_redirects, timeout, extensions)
#     822     warnings.warn(message, DeprecationWarning)
#     824 request = self.build_request(
#     825     method=method,
#     826     url=url,
#    (...)
#     835     extensions=extensions,
#     836 )
# --> 837 return self.send(request, auth=auth, follow_redirects=follow_redirects)
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_client.py:926, in Client.send(self, request, stream, auth, follow_redirects)
#     922 self._set_timeout(request)
#     924 auth = self._build_request_auth(request, auth)
# --> 926 response = self._send_handling_auth(
#     927     request,
#     928     auth=auth,
#     929     follow_redirects=follow_redirects,
#     930     history=[],
#     931 )
#     932 try:
#     933     if not stream:
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_client.py:954, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     951 request = next(auth_flow)
#     953 while True:
# --> 954     response = self._send_handling_redirects(
#     955         request,
#     956         follow_redirects=follow_redirects,
#     957         history=history,
#     958     )
#     959     try:
#     960         try:
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_client.py:991, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     988 for hook in self._event_hooks["request"]:
#     989     hook(request)
# --> 991 response = self._send_single_request(request)
#     992 try:
#     993     for hook in self._event_hooks["response"]:
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_client.py:1027, in Client._send_single_request(self, request)
#    1022     raise RuntimeError(
#    1023         "Attempted to send an async request with a sync Client instance."
#    1024     )
#    1026 with request_context(request=request):
# -> 1027     response = transport.handle_request(request)
#    1029 assert isinstance(response.stream, SyncByteStream)
#    1031 response.request = request
#
# File /opt/conda/lib/python3.10/site-packages/httpx/_transports/default.py:236, in HTTPTransport.handle_request(self, request)
#     223 req = httpcore.Request(
#     224     method=request.method,
#     225     url=httpcore.URL(
#    (...)
#     233     extensions=request.extensions,
#     234 )
#     235 with map_httpcore_exceptions():
# --> 236     resp = self._pool.handle_request(req)
#     238 assert isinstance(resp.stream, typing.Iterable)
#     240 return Response(
#     241     status_code=resp.status,
#     242     headers=resp.headers,
#     243     stream=ResponseStream(resp.stream),
#     244     extensions=resp.extensions,
#     245 )
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:216, in ConnectionPool.handle_request(self, request)
#     213         closing = self._assign_requests_to_connections()
#     215     self._close_connections(closing)
# --> 216     raise exc from None
#     218 # Return the response. Note that in this case we still have to manage
#     219 # the point at which the response is closed.
#     220 assert isinstance(response.stream, Iterable)
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/connection_pool.py:196, in ConnectionPool.handle_request(self, request)
#     192 connection = pool_request.wait_for_connection(timeout=timeout)
#     194 try:
#     195     # Send the request on the assigned connection.
# --> 196     response = connection.handle_request(
#     197         pool_request.request
#     198     )
#     199 except ConnectionNotAvailable:
#     200     # In some cases a connection may initially be available to
#     201     # handle a request, but then become unavailable.
#     202     #
#     203     # In this case we clear the connection and try again.
#     204     pool_request.clear_connection()
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/connection.py:101, in HTTPConnection.handle_request(self, request)
#      98     self._connect_failed = True
#      99     raise exc
# --> 101 return self._connection.handle_request(request)
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/http11.py:143, in HTTP11Connection.handle_request(self, request)
#     141     with Trace("response_closed", logger, request) as trace:
#     142         self._response_closed()
# --> 143 raise exc
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/http11.py:113, in HTTP11Connection.handle_request(self, request)
#     102     pass
#     104 with Trace(
#     105     "receive_response_headers", logger, request, kwargs
#     106 ) as trace:
#     107     (
#     108         http_version,
#     109         status,
#     110         reason_phrase,
#     111         headers,
#     112         trailing_data,
# --> 113     ) = self._receive_response_headers(**kwargs)
#     114     trace.return_value = (
#     115         http_version,
#     116         status,
#     117         reason_phrase,
#     118         headers,
#     119     )
#     121 network_stream = self._network_stream
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/http11.py:186, in HTTP11Connection._receive_response_headers(self, request)
#     183 timeout = timeouts.get("read", None)
#     185 while True:
# --> 186     event = self._receive_event(timeout=timeout)
#     187     if isinstance(event, h11.Response):
#     188         break
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_sync/http11.py:224, in HTTP11Connection._receive_event(self, timeout)
#     221     event = self._h11_state.next_event()
#     223 if event is h11.NEED_DATA:
# --> 224     data = self._network_stream.read(
#     225         self.READ_NUM_BYTES, timeout=timeout
#     226     )
#     228     # If we feed this case through h11 we'll raise an exception like:
#     229     #
#     230     #     httpcore.RemoteProtocolError: can't handle event type
#    (...)
#     234     # perspective. Instead we handle this case distinctly and treat
#     235     # it as a ConnectError.
#     236     if data == b"" and self._h11_state.their_state == h11.SEND_RESPONSE:
#
# File /opt/conda/lib/python3.10/site-packages/httpcore/_backends/sync.py:126, in SyncStream.read(self, max_bytes, timeout)
#     124 with map_exceptions(exc_map):
#     125     self._sock.settimeout(timeout)
# --> 126     return self._sock.recv(max_bytes)
#
# KeyboardInterrupt:

# %%
print(info)
img = Image.open(image_file)
# Out:
# ['/root/home/data_jpg/pos_rgb_0_tile_405.jpg', '/root/home/data_jpg/pos_rgb_1_tile_405.jpg', '/root/home/data_jpg/pos_rgb_2_tile_405.jpg', '/root/home/data_jpg/pos_rgb_3_tile_405.jpg', '/root/home/data_jpg/pos_rgb_4_tile_405.jpg', '/root/home/data_jpg/pos_rgb_5_tile_405.jpg']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 print(info)
# ----> 2 img = Image.open(image_file)
#
# NameError: name 'image_file' is not defined

# %%
pwd
# Out:
# '/root/home/code'
